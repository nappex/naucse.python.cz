# %% [markdown]
# # Pandas - datové typy a manipulace se sloupci
#
# V minulé lekci jsme si představili knihovnu pandas a její základní třídy: `Series`, `DataFrame` a `Index`. Brali jsme je ovšem jako statické objekty, které jsme si pouze prohlíželi.
#
# V této lekci začneme upravovat existující tabulky. Ukážeme si:
#
# * jak přidat či ubrat sloupce a řádky
# * jak změnit hodnotu konkrétní buňky
# * jaké datové typy se hodí pro který účel
# * aritmetické a logické operace, které lze se sloupci provádět
# * filtrování a řazení řádků
#
# A jelikož o výsledky práce určitě nechceš přijít, přijde nakonec vhod i ukládání výsledků do externích souborů.

# %%
# Obligátní import
import pandas as pd

# %% [markdown]
# ## Manipulace s DataFrames
#
# Pro rozehřátí budeme pracovat s malou tabulkou obsahující několik základních informací o planetách, které snadno najdeš např. na [wikipedii](https://en.wikipedia.org/wiki/Planet).

# %%
planety = pd.DataFrame({
    "jmeno": ["Merkur", "Venuše", "Země", "Mars", "Jupiter", "Saturn", "Uran", "Neptun"],
    "symbol": ["☿", "♀", "⊕", "♂", "♃", "♄", "♅", "♆"],
    "obezna_poloosa": [0.39, 0.72, 1.00, 1.52, 5.20, 9.54, 19.22, 30.06],
    "obezna_doba": [0.24, 0.62, 1, 1.88, 11.86, 29.46, 84.01, 164.8],
})
planety = planety.set_index("jmeno")    # S jmenným indexem se ti bude snáze pracovat
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba
# jmeno
# Merkur       ☿            0.39         0.24
# Venuše       ♀            0.72         0.62
# Země         ⊕            1.00         1.00
# Mars         ♂            1.52         1.88
# Jupiter      ♃            5.20        11.86
# Saturn       ♄            9.54        29.46
# Uran         ♅           19.22        84.01
# Neptun       ♆           30.06       164.80

# %% [markdown]
# ### Přidání nového sloupce
#
# Když chceme přidat nový sloupec (`Series`), přiřadíme ho do `DataFrame` jako hodnotu do slovníku - tedy v hranatých závorkách s názvem sloupce. Dobrá zpráva je, že stejně jako v konstruktoru si `pandas` "poradí" jak se `Series`, tak s obyčejným seznamem.
#
# V našem konkrétním případě si najdeme a přidáme počet známých měsíců (velkých i malých).

# %%
mesice = [0, 0, 1, 2, 79, 82, 27, 14]      # Alternativně mesice = pd.Series([...])
planety["mesice"] = mesice
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice
# jmeno
# Merkur       ☿            0.39         0.24       0
# Venuše       ♀            0.72         0.62       0
# Země         ⊕            1.00         1.00       1
# Mars         ♂            1.52         1.88       2
# Jupiter      ♃            5.20        11.86      79
# Saturn       ♄            9.54        29.46      82
# Uran         ♅           19.22        84.01      27
# Neptun       ♆           30.06       164.80      14

# %% [markdown]
# 💡 V tomto případě jsme přímo upravili existující `DataFrame`. Většina metod / operací v `pandas` (už znáš např. `set_index`) ve výchozím nastavení vždy vrací nový objekt - je to dobrým zvykem, který budeme dodržovat. Přiřazování sloupců je jednou z akceptovaných výjimek tohoto jinak uznávaného pravidla, zejména když se tabulka upravuje jen v úzkém rozsahu řádků kódů.
#
# `DataFrame` však nabízí ještě metodu `assign`, která nemění tabulku, ale vytváří její kopii s přidanými (nebo nahrazenými) sloupci. Pokud se chceš vyhnout nepříjemnému sledování, kterou tabulku jsi změnil/a či nikoliv, `assign` ti můžeme jen doporučit.

# %%
# Nový dočasný DataFrame
planety.assign(
    je_stavebnice=[True, False, False, False, False, False, False, False],
    ma_vztah_k_vestonicim=[False, True, False, False, False, False, False, False],
)

# Objekt `planety` zůstal nezměněn.
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice  je_stavebnice  \
# jmeno
# Merkur       ☿            0.39         0.24       0           True
# Venuše       ♀            0.72         0.62       0          False
# Země         ⊕            1.00         1.00       1          False
# Mars         ♂            1.52         1.88       2          False
# Jupiter      ♃            5.20        11.86      79          False
# Saturn       ♄            9.54        29.46      82          False
# Uran         ♅           19.22        84.01      27          False
# Neptun       ♆           30.06       164.80      14          False
#
#          ma_vztah_k_vestonicim
# jmeno
# Merkur                   False
# Venuše                    True
# Země                     False
# Mars                     False
# Jupiter                  False
# Saturn                   False
# Uran                     False
# Neptun                   False

# %% [markdown]
# **Úkol**: Zkus (jedním či druhým způsobem) přidat sloupec s rokem objevu (`"objeveno"`). Údaje najdeš např. zde: https://cs.wikipedia.org/wiki/Slune%C4%8Dn%C3%AD_soustava.

# %% [markdown]
# Pro hodnoty nového sloupce lze použít i jednu skalární hodnotu (v praxi se ale s touto potřebou nepotkáme tak často):

# %%
planety["je_planeta"] = True

# %% [markdown]
# ### Přidání nového řádku
#
# Když se strojem času vrátíme do dětství (nebo rané dospělosti) autorů těchto materiálů, tedy před rok 2006, kdy se v Praze konal astronomický kongres, který definoval pojem "planeta" (ale ne před rok 1930!), přibude nám nová planeta: Pluto.
#
# Do naší tabulky ho coby nový řádek vložíme pomocí indexeru `loc`, který jsme již dříve používali pro "koukání" do tabulky:

# %%
planety.loc["Pluto"] = ["♇", 39.48, 247.94, 5, True]   # Seznam hodnot v řádku
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice  je_planeta
# jmeno
# Merkur       ☿            0.39         0.24       0        True
# Venuše       ♀            0.72         0.62       0        True
# Země         ⊕            1.00         1.00       1        True
# Mars         ♂            1.52         1.88       2        True
# Jupiter      ♃            5.20        11.86      79        True
# Saturn       ♄            9.54        29.46      82        True
# Uran         ♅           19.22        84.01      27        True
# Neptun       ♆           30.06       164.80      14        True
# Pluto        ♇           39.48       247.94       5        True

# %% [markdown]
# **Úkol:** Zkus přidat Slunce nebo nějakou zcela smyšlenou planetu.

# %% [markdown]
# ### Změna hodnoty buňky
#
# "Indexery" `.loc` a `.iloc` se dvěma argumenty v hranatých závorkách odkazují přímo na konkrétní buňku, a přiřazením do nich (opět, podobně jako ve slovníku) se hodnota na příslušné místo zapíše. Jen je třeba zachovat pořadí (řádek, sloupec).
#
# Vrátíme se opět do současnosti a Pluto zbavíme jeho statutu:

# %%
planety.loc["Pluto", "je_planeta"] = False
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice  je_planeta
# jmeno
# Merkur       ☿            0.39         0.24       0        True
# Venuše       ♀            0.72         0.62       0        True
# Země         ⊕            1.00         1.00       1        True
# Mars         ♂            1.52         1.88       2        True
# Jupiter      ♃            5.20        11.86      79        True
# Saturn       ♄            9.54        29.46      82        True
# Uran         ♅           19.22        84.01      27        True
# Neptun       ♆           30.06       164.80      14        True
# Pluto        ♇           39.48       247.94       5       False

# %% [markdown]
# **⚠ Pozor:** Podobně jako u slovníku, ale možná poněkud neintuitivně, je možné zapsat hodnotu do řádku i sloupce, které neexistují!

# %%
planety_bad = planety.copy()     # Pro jistotu si uděláme kopii

planety_bad.loc["Zeme", "planeta"] = True
planety_bad
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice je_planeta planeta
# jmeno
# Merkur       ☿            0.39         0.24     0.0       True     NaN
# Venuše       ♀            0.72         0.62     0.0       True     NaN
# Země         ⊕            1.00         1.00     1.0       True     NaN
# Mars         ♂            1.52         1.88     2.0       True     NaN
# Jupiter      ♃            5.20        11.86    79.0       True     NaN
# Saturn       ♄            9.54        29.46    82.0       True     NaN
# Uran         ♅           19.22        84.01    27.0       True     NaN
# Neptun       ♆           30.06       164.80    14.0       True     NaN
# Pluto        ♇           39.48       247.94     5.0      False     NaN
# Zeme       NaN             NaN          NaN     NaN        NaN    True

# %% [markdown]
# 💡 Jistě se ptáš, co znamená **NaN** v tabulce. Tato hodnota, více slovy "not a number", označuje chybějící, neplatnou nebo neznámou hodnotu (v našem případě jsme ji nezadali, a tedy se není co divit). O problematice chybějících hodnot (a jejich napravování) si budeme povídat někdy příště, prozatím se jimi nenech znervóznit.

# %% [markdown]
# Přiřazovat je možné i do rozsahů v indexech - jen je potřeba hlídat, aby přiřazovaná hodnota či hodnoty byly buď skalárem, nebo měly stejný tvar (počet řádků a sloupců) jako oblast, do které přiřazujeme:

# %%
planety.loc["Merkur":"Mars", "je_obr"] = False
planety.loc["Jupiter":"Neptun", "je_obr"] = [True, True, True, True]
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice  je_planeta je_obr
# jmeno
# Merkur       ☿            0.39         0.24       0        True  False
# Venuše       ♀            0.72         0.62       0        True  False
# Země         ⊕            1.00         1.00       1        True  False
# Mars         ♂            1.52         1.88       2        True  False
# Jupiter      ♃            5.20        11.86      79        True   True
# Saturn       ♄            9.54        29.46      82        True   True
# Uran         ♅           19.22        84.01      27        True   True
# Neptun       ♆           30.06       164.80      14        True   True
# Pluto        ♇           39.48       247.94       5       False    NaN

# %% [markdown]
# **Úkol:** Shodou okolností (nebo jde o astronomickou nevyhnutelnost?) mají všichni planetární obři alespoň nějaký prstenec. Dokážeš jednoduše vytvořit sloupec `"ma_prstenec"`?

# %% [markdown]
# ### Odstranění řádku
#
# Pro odebrání sloupce či řádku z DataFrame slouží metoda `drop`. Její první argument očekává označení (index) jednoho nebo více řádků či sloupců, které chceš odebrat. Argument `axis` označuje, ve které dimenzi se operace má aplikovat - můžeš použít buď číslo 0 či 1 (odpovídá pořadí od nuly, ve kterém se uvádějí klíče při odkazování na buňky), anebo pojmenování dané dimenze:
#
# Osa (axis):
#
# - 0 nebo "rows" nebo "index" → řádky
# - 1 nebo "columns" → sloupce
#
# (Tento argument používají i četné další metody a funkce, proto se ujisti, že mu rozumíš).
#
# Když už jsme se vrátili do budoucnosti (resp. současnosti), vypořádejme se nemilosrdně s Plutem (pro metodu `drop` je výchozí hodnotou argumentu `axis` 0, a tedy to nemusíme psát):

# %%
planety = planety.drop("Pluto")   # Přidej axis="rows", chceš-li být explicitní
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice  je_planeta je_obr
# jmeno
# Merkur       ☿            0.39         0.24       0        True  False
# Venuše       ♀            0.72         0.62       0        True  False
# Země         ⊕            1.00         1.00       1        True  False
# Mars         ♂            1.52         1.88       2        True  False
# Jupiter      ♃            5.20        11.86      79        True   True
# Saturn       ♄            9.54        29.46      82        True   True
# Uran         ♅           19.22        84.01      27        True   True
# Neptun       ♆           30.06       164.80      14        True   True

# %% [markdown]
# **Úkol:** Zkus vytvořit tabulku bez Uranu a Neptunu (jedním příkazem).

# %% [markdown]
# ### Odstranění sloupce
#
# U sloupce funguje metoda `drop` velmi podobně, jen tentokrát argument `axis` uvést musíme.
#
# Odstraňme zbytečný sloupec s informační hodnotou na úrovni "stěrače stírají, klakson troubí"...

# %%
planety = planety.drop("je_planeta", axis="columns")   
planety
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice je_obr
# jmeno
# Merkur       ☿            0.39         0.24       0  False
# Venuše       ♀            0.72         0.62       0  False
# Země         ⊕            1.00         1.00       1  False
# Mars         ♂            1.52         1.88       2  False
# Jupiter      ♃            5.20        11.86      79   True
# Saturn       ♄            9.54        29.46      82   True
# Uran         ♅           19.22        84.01      27   True
# Neptun       ♆           30.06       164.80      14   True

# %% [markdown]
# <span style="color: red; left: 50%; top: 0.5em; font-weight: bold; position: absolute; opacity: 0.3; width: 0px; height: 0px; font-size: 6em">⛧</span> Metoda `drop`, v souladu s výše zmíněnou konvencí, vrací nový `DataFrame` (a proto výsledek operace musíme přiřadit do `planety`). Pokud chceš operovat rovnou na tabulce, můžeš použít příkaz `del` (funguje stejně jako u slovníku) nebo poprosit pandí bohy (a autory těchto materiálů) o odpuštění a přidat argument `inplace=True` (tento argument lze, bohužel, použít i mnoha dalších operací):

# %%
# Jen na vlastní nebezpečí

# Alternativa 1)
# del planety["je_planeta"]

# Alternativa 2)
# planety.drop("je_planeta", axis=1, inplace=True)

# %% [markdown]
# Ale opravdu to nedělej!

# %% [markdown]
# #### Datové typy
#
# Jak už jsme předeslali, datové typy v pandas se trochu liší od typů v Pythonu a nejsou to v pravém slova smyslu třídy, ale naštěstí konverze mezi nimi je často automatická a "chovající se dle očekávání".

# %% [markdown]
# #### Příprava dat
#
# V datovém kurzu budeme využívat různých datových sad (obvykle větších - takových, kde není praktické je celé zapsat v konstruktoru). Nyní opustíme planety a podíváme se na některé zajímavé charakteristiky zemí kolem světa (ježto definice toho, co je to země, je poněkud vágní, bereme v potaz členy OSN), zachycené k jednomu konkrétnímu roku uplynulé dekády (protože ne vždy jsou všechny údaje k dispozici, bereme poslední rok, kde je známo dost ukazatelů). Data pocházejí povětšinou z projektu [Gapminder](https://www.gapminder.org/), doplnili jsme je jen o několik dalších informací z wikipedie.
#
# Následující kód (nemusíš mu rozumět) stáhne potřebný soubor a uloží ho v místním adresáři. Alternativně ho můžeš stáhnout manuálně z [https://raw.githubusercontent.com/janpipek/data-pro-pyladies/master/data/countries.csv](https://raw.githubusercontent.com/janpipek/data-pro-pyladies/master/data/countries.csv).

# %%
# Nutné importy ze standardní knihovny
import os
from urllib.request import urlopen

# Seznam souborů (viz níže)
zdroj = "https://raw.githubusercontent.com/janpipek/data-pro-pyladies/master/data/countries.csv"
jmeno = zdroj.rsplit("/")[-1]

if not os.path.exists(jmeno):        
    print(f"Soubor {jmeno} ještě není stažen, jdeme na to...")

    # Sendvičově otevřeme výstup (soubor na disku) i vstup (webovou stránku)
    with open(jmeno, "wb") as outfile:  # Pozor - binární mód
        with urlopen(url) as inpage:
            # A jen přepíšeme obsah 
            outfile.write(inpage.read())
    print(f"Soubor {jmeno} úspěšně stažen.")
else:
    print(f"Soubor {jmeno} už byl stažen, použijeme místní kopii.")
# Out:
# Soubor countries.csv už byl stažen, použijeme místní kopii.

# %% [markdown]
# A otevřeme ho pomocí již známé funkce `read_csv` (Poznámka: `pandas` umí otevřít soubor i přímo z internetu, ale raději použijeme místní kopii, aby ses mohl/a k práci vrátit i off-line).

# %%
# Místo `set_index` vybereme index rovnou při načítání
countries = pd.read_csv("countries.csv", index_col="name")

countries = countries.sort_index()
countries
# Out:
#                         iso             world_6region world_4region  \
# name
# Afghanistan             AFG                south_asia          asia
# Albania                 ALB       europe_central_asia        europe
# Algeria                 DZA  middle_east_north_africa        africa
# Andorra                 AND       europe_central_asia        europe
# Angola                  AGO        sub_saharan_africa        africa
# Antigua and Barbuda     ATG                   america      americas
# Argentina               ARG                   america      americas
# Armenia                 ARM       europe_central_asia        europe
# Australia               AUS         east_asia_pacific          asia
# Austria                 AUT       europe_central_asia        europe
# Azerbaijan              AZE       europe_central_asia        europe
# Bahamas                 BHS                   america      americas
# Bahrain                 BHR  middle_east_north_africa          asia
# Bangladesh              BGD                south_asia          asia
# Barbados                BRB                   america      americas
# Belarus                 BLR       europe_central_asia        europe
# Belgium                 BEL       europe_central_asia        europe
# Belize                  BLZ                   america      americas
# Benin                   BEN        sub_saharan_africa        africa
# Bhutan                  BTN                south_asia          asia
# Bolivia                 BOL                   america      americas
# Bosnia and Herzegovina  BIH       europe_central_asia        europe
# Botswana                BWA        sub_saharan_africa        africa
# Brazil                  BRA                   america      americas
# Brunei                  BRN         east_asia_pacific          asia
# Bulgaria                BGR       europe_central_asia        europe
# Burkina Faso            BFA        sub_saharan_africa        africa
# Burundi                 BDI        sub_saharan_africa        africa
# Cambodia                KHM         east_asia_pacific          asia
# Cameroon                CMR        sub_saharan_africa        africa
# ...                     ...                       ...           ...
# Sudan                   SDN        sub_saharan_africa        africa
# Suriname                SUR                   america      americas
# Swaziland               SWZ        sub_saharan_africa        africa
# Sweden                  SWE       europe_central_asia        europe
# Switzerland             CHE       europe_central_asia        europe
# Syria                   SYR  middle_east_north_africa          asia
# Tajikistan              TJK       europe_central_asia          asia
# Tanzania                TZA        sub_saharan_africa        africa
# Thailand                THA         east_asia_pacific          asia
# Timor-Leste             TLS         east_asia_pacific          asia
# Togo                    TGO        sub_saharan_africa        africa
# Tonga                   TON         east_asia_pacific          asia
# Trinidad and Tobago     TTO                   america      americas
# Tunisia                 TUN  middle_east_north_africa        africa
# Turkey                  TUR       europe_central_asia        europe
# Turkmenistan            TKM       europe_central_asia          asia
# Tuvalu                  TUV         east_asia_pacific          asia
# Uganda                  UGA        sub_saharan_africa        africa
# Ukraine                 UKR       europe_central_asia        europe
# United Arab Emirates    ARE  middle_east_north_africa          asia
# United Kingdom          GBR       europe_central_asia        europe
# United States           USA                   america      americas
# Uruguay                 URY                   america      americas
# Uzbekistan              UZB       europe_central_asia          asia
# Vanuatu                 VUT         east_asia_pacific          asia
# Venezuela               VEN                   america      americas
# Vietnam                 VNM         east_asia_pacific          asia
# Yemen                   YEM  middle_east_north_africa          asia
# Zambia                  ZMB        sub_saharan_africa        africa
# Zimbabwe                ZWE        sub_saharan_africa        africa
#
#                               income_groups  is_eu  is_oecd eu_accession  \
# name
# Afghanistan                      low_income  False    False          NaN
# Albania                 upper_middle_income  False    False          NaN
# Algeria                 upper_middle_income  False    False          NaN
# Andorra                         high_income  False    False          NaN
# Angola                  upper_middle_income  False    False          NaN
# Antigua and Barbuda             high_income  False    False          NaN
# Argentina               upper_middle_income  False    False          NaN
# Armenia                 lower_middle_income  False    False          NaN
# Australia                       high_income  False     True          NaN
# Austria                         high_income   True     True   1995-01-01
# Azerbaijan              upper_middle_income  False    False          NaN
# Bahamas                         high_income  False    False          NaN
# Bahrain                         high_income  False    False          NaN
# Bangladesh                       low_income  False    False          NaN
# Barbados                        high_income  False    False          NaN
# Belarus                 upper_middle_income  False    False          NaN
# Belgium                         high_income   True     True   1952-07-23
# Belize                  upper_middle_income  False    False          NaN
# Benin                            low_income  False    False          NaN
# Bhutan                  lower_middle_income  False    False          NaN
# Bolivia                 lower_middle_income  False    False          NaN
# Bosnia and Herzegovina  upper_middle_income  False    False          NaN
# Botswana                upper_middle_income  False    False          NaN
# Brazil                  upper_middle_income  False    False          NaN
# Brunei                          high_income  False    False          NaN
# Bulgaria                upper_middle_income   True    False   2007-01-01
# Burkina Faso                     low_income  False    False          NaN
# Burundi                          low_income  False    False          NaN
# Cambodia                         low_income  False    False          NaN
# Cameroon                lower_middle_income  False    False          NaN
# ...                                     ...    ...      ...          ...
# Sudan                   lower_middle_income  False    False          NaN
# Suriname                upper_middle_income  False    False          NaN
# Swaziland               lower_middle_income  False    False          NaN
# Sweden                          high_income   True     True   1995-01-01
# Switzerland                     high_income  False     True          NaN
# Syria                   lower_middle_income  False    False          NaN
# Tajikistan                       low_income  False    False          NaN
# Tanzania                         low_income  False    False          NaN
# Thailand                upper_middle_income  False    False          NaN
# Timor-Leste             lower_middle_income  False    False          NaN
# Togo                             low_income  False    False          NaN
# Tonga                   upper_middle_income  False    False          NaN
# Trinidad and Tobago             high_income  False    False          NaN
# Tunisia                 upper_middle_income  False    False          NaN
# Turkey                  upper_middle_income  False     True          NaN
# Turkmenistan            upper_middle_income  False    False          NaN
# Tuvalu                  upper_middle_income  False    False          NaN
# Uganda                           low_income  False    False          NaN
# Ukraine                 lower_middle_income  False    False          NaN
# United Arab Emirates            high_income  False    False          NaN
# United Kingdom                  high_income   True     True   1973-01-01
# United States                   high_income  False     True          NaN
# Uruguay                         high_income  False    False          NaN
# Uzbekistan              lower_middle_income  False    False          NaN
# Vanuatu                 lower_middle_income  False    False          NaN
# Venezuela               upper_middle_income  False    False          NaN
# Vietnam                 lower_middle_income  False    False          NaN
# Yemen                   lower_middle_income  False    False          NaN
# Zambia                  lower_middle_income  False    False          NaN
# Zimbabwe                         low_income  False    False          NaN
#
#                         year       area   population  alcohol_adults  bmi_men  \
# name
# Afghanistan             2018   652860.0   34500000.0            0.03    20.62
# Albania                 2018    28750.0    3238000.0            7.29    26.45
# Algeria                 2018  2381740.0   36980000.0            0.69    24.60
# Andorra                 2017      470.0      88910.0           10.17    27.63
# Angola                  2018  1246700.0   20710000.0            5.57    22.25
# Antigua and Barbuda     2018      440.0      91400.0            8.17    25.77
# Argentina               2018  2780400.0   41470000.0            9.35    27.50
# Armenia                 2018    29740.0    3118000.0           13.66    25.36
# Australia               2018  7741220.0   23210000.0           10.21    27.56
# Austria                 2018    83879.0    8441000.0           12.40    26.47
# Azerbaijan              2018    86600.0    9533000.0           13.34    25.65
# Bahamas                 2018    13880.0     355200.0            8.65    27.25
# Bahrain                 2018      771.0    1377000.0            4.19    27.84
# Bangladesh              2018   147630.0  154400000.0            0.17    20.40
# Barbados                2018      430.0     275100.0            6.42    26.38
# Belarus                 2018   207600.0    9498000.0           18.85    26.16
# Belgium                 2018    30530.0   10820000.0           10.41    26.76
# Belize                  2018    22970.0     330700.0            5.92    27.02
# Benin                   2018   114760.0    9607000.0            2.08    22.42
# Bhutan                  2018    38394.0     762300.0            0.54    22.82
# Bolivia                 2018  1098580.0   10410000.0            5.78    24.43
# Bosnia and Herzegovina  2018    51210.0    3736000.0            9.60    26.61
# Botswana                2018   581730.0    2075000.0            6.97    22.13
# Brazil                  2018  8515770.0  200100000.0           10.08    25.79
# Brunei                  2018     5770.0     419800.0            1.86    24.18
# Bulgaria                2018   111000.0    7349000.0           11.40    26.54
# Burkina Faso            2018   274220.0   18010000.0            7.32    21.27
# Burundi                 2018    27830.0    8911000.0            9.65    21.50
# Cambodia                2018   181040.0   14660000.0            4.71    20.80
# Cameroon                2018   475440.0   20910000.0            7.90    23.68
# ...                      ...        ...          ...             ...      ...
# Sudan                   2018  1879357.5   35940000.0            2.56    22.40
# Suriname                2018   163820.0     538900.0            6.56    25.50
# Swaziland               2018    17360.0    1237000.0            5.05    23.17
# Sweden                  2018   447420.0    9546000.0            9.50    26.38
# Switzerland             2018    41290.0    7762000.0           11.41    26.20
# Syria                   2018   185180.0   21470000.0            1.49    26.92
# Tajikistan              2018   141376.0    7184000.0            3.39    23.78
# Tanzania                2018   947300.0   49150000.0            7.86    22.48
# Thailand                2018   513120.0   70240000.0            7.08    23.01
# Timor-Leste             2018    14870.0    1224000.0            0.74    20.59
# Togo                    2018    56790.0    6413000.0            1.92    21.88
# Tonga                   2018      750.0     105300.0            3.92    31.00
# Trinidad and Tobago     2018     5130.0    1355000.0            6.16    26.40
# Tunisia                 2018   163610.0   10810000.0            1.05    25.16
# Turkey                  2018   785350.0   75360000.0            3.02    26.70
# Turkmenistan            2018   488100.0    5235000.0            5.00    25.25
# Tuvalu                  2017       30.0       9888.0            2.14      NaN
# Uganda                  2018   241550.0   36760000.0           16.40    22.36
# Ukraine                 2018   603550.0   44700000.0           17.47    25.42
# United Arab Emirates    2018    83600.0    8208000.0            0.52    28.05
# United Kingdom          2018   243610.0   63180000.0           13.24    27.39
# United States           2018  9831510.0  318500000.0            9.70    28.46
# Uruguay                 2018   176220.0    3403000.0            8.99    26.39
# Uzbekistan              2018   447400.0   28400000.0            3.61    25.32
# Vanuatu                 2018    12190.0     257800.0            0.96    26.79
# Venezuela               2018   912050.0   30340000.0            7.60    27.45
# Vietnam                 2018   330967.0   90660000.0            3.91    20.92
# Yemen                   2018   527970.0   26360000.0            0.20    24.44
# Zambia                  2018   752610.0   14310000.0            3.56    20.68
# Zimbabwe                2018   390760.0   13330000.0            4.96    22.03
#
#                         bmi_women  car_deaths_per_100000_people  \
# name
# Afghanistan                 21.07                           NaN
# Albania                     25.66                         5.978
# Algeria                     26.37                           NaN
# Andorra                     26.43                           NaN
# Angola                      23.48                           NaN
# Antigua and Barbuda         27.51                           NaN
# Argentina                   27.47                         8.682
# Armenia                     27.13                         7.899
# Australia                   26.88                         5.335
# Austria                     25.09                         3.541
# Azerbaijan                  27.51                         5.279
# Bahamas                     29.14                         9.408
# Bahrain                     28.79                         8.190
# Bangladesh                  20.55                         4.401
# Barbados                    29.22                         8.770
# Belarus                     26.64                         8.454
# Belgium                     25.14                         5.427
# Belize                      29.82                        23.040
# Benin                       23.74                        13.120
# Bhutan                      22.88                           NaN
# Bolivia                     26.86                        11.740
# Bosnia and Herzegovina      26.36                         6.405
# Botswana                    26.09                        29.570
# Brazil                      25.99                         1.872
# Brunei                      22.89                        11.670
# Bulgaria                    25.52                         9.662
# Burkina Faso                21.63                        19.400
# Burundi                     21.28                           NaN
# Cambodia                    21.70                         1.972
# Cameroon                    24.95                        20.460
# ...                           ...                           ...
# Sudan                       23.16                        11.790
# Suriname                    27.75                         8.573
# Swaziland                   28.45                        20.150
# Sweden                      25.15                         2.737
# Switzerland                 24.07                         2.342
# Syria                       28.87                           NaN
# Tajikistan                  23.85                         9.448
# Tanzania                    23.08                        16.550
# Thailand                    24.39                         2.101
# Timor-Leste                 21.51                           NaN
# Togo                        22.74                           NaN
# Tonga                       34.26                         3.850
# Trinidad and Tobago         28.28                         9.447
# Tunisia                     27.94                        19.290
# Turkey                      28.25                         7.189
# Turkmenistan                24.66                           NaN
# Tuvalu                        NaN                           NaN
# Uganda                      22.48                        13.690
# Ukraine                     26.23                         8.771
# United Arab Emirates        29.61                        31.850
# United Kingdom              26.94                         3.377
# United States               28.34                         9.523
# Uruguay                     26.59                         2.566
# Uzbekistan                  25.43                         6.418
# Vanuatu                     28.46                           NaN
# Venezuela                   28.13                         7.332
# Vietnam                     21.07                           NaN
# Yemen                       26.11                           NaN
# Zambia                      23.05                        11.260
# Zimbabwe                    24.65                        20.850
#
#                         calories_per_day  infant_mortality  life_expectancy  \
# name
# Afghanistan                       2090.0              66.3            58.69
# Albania                           3193.0              12.5            78.01
# Algeria                           3296.0              21.9            77.86
# Andorra                              NaN               2.1            82.55
# Angola                            2473.0              96.0            65.19
# Antigua and Barbuda               2417.0               5.8            77.60
# Argentina                         3229.0              11.1            76.97
# Armenia                           2928.0              12.6            75.97
# Australia                         3276.0               3.0            82.87
# Austria                           3768.0               2.9            81.84
# Azerbaijan                        3118.0              27.9            72.30
# Bahamas                           2670.0               9.9            74.10
# Bahrain                              NaN               5.3            77.18
# Bangladesh                        2450.0              30.7            73.41
# Barbados                          2937.0              12.0            76.84
# Belarus                           3250.0               3.4            73.76
# Belgium                           3733.0               3.3            81.23
# Belize                            2751.0              14.2            72.45
# Benin                             2619.0              64.2            64.98
# Bhutan                               NaN              27.2            74.83
# Bolivia                           2256.0              30.6            73.97
# Bosnia and Herzegovina            3154.0               5.1            77.93
# Botswana                          2326.0              34.8            66.92
# Brazil                            3263.0              14.6            75.70
# Brunei                            2985.0               8.6            77.36
# Bulgaria                          2829.0               9.3            75.32
# Burkina Faso                      2720.0              60.9            61.60
# Burundi                              NaN              54.1            61.14
# Cambodia                          2477.0              24.6            69.35
# Cameroon                          2671.0              57.1            61.22
# ...                                  ...               ...              ...
# Sudan                             2336.0              47.6            68.77
# Suriname                          2753.0              19.0            71.62
# Swaziland                         2329.0              44.5            58.64
# Sweden                            3179.0               2.4            82.37
# Switzerland                       3391.0               3.4            83.45
# Syria                                NaN              11.1            69.82
# Tajikistan                        2201.0              38.5            72.19
# Tanzania                          2208.0              35.2            65.46
# Thailand                          2784.0              10.5            78.15
# Timor-Leste                       2131.0              44.7            73.34
# Togo                              2454.0              52.3            63.09
# Tonga                                NaN              14.4            70.70
# Trinidad and Tobago               3052.0              18.2            73.37
# Tunisia                           3349.0              12.1            77.96
# Turkey                            3706.0              11.6            79.61
# Turkmenistan                      2840.0              43.7            70.48
# Tuvalu                               NaN              22.8              NaN
# Uganda                            2130.0              37.7            62.86
# Ukraine                           3138.0               7.7            72.29
# United Arab Emirates              3280.0               5.9            76.89
# United Kingdom                    3424.0               3.5            81.19
# United States                     3682.0               5.6            79.14
# Uruguay                           3050.0               8.7            77.57
# Uzbekistan                        2760.0              33.9            70.50
# Vanuatu                           2836.0              23.1            64.30
# Venezuela                         2631.0              12.9            75.91
# Vietnam                           2745.0              17.3            74.88
# Yemen                             2223.0              33.8            67.14
# Zambia                            1930.0              43.3            59.45
# Zimbabwe                          2110.0              46.6            60.18
#
#                         life_expectancy_female  life_expectancy_male  \
# name
# Afghanistan                             65.812                63.101
# Albania                                 80.737                76.693
# Algeria                                 77.784                75.279
# Andorra                                    NaN                   NaN
# Angola                                  64.939                59.213
# Antigua and Barbuda                     79.028                74.154
# Argentina                               80.572                73.151
# Armenia                                 77.952                71.589
# Australia                               85.102                81.390
# Austria                                 84.249                79.585
# Azerbaijan                              75.283                69.150
# Bahamas                                 78.894                72.905
# Bahrain                                 78.293                76.318
# Bangladesh                              74.937                71.484
# Barbados                                78.547                73.758
# Belarus                                 78.583                67.693
# Belgium                                 83.751                79.131
# Belize                                  73.828                68.088
# Benin                                   62.960                59.867
# Bhutan                                  71.277                70.567
# Bolivia                                 72.414                67.317
# Bosnia and Herzegovina                  79.729                74.741
# Botswana                                70.753                65.719
# Brazil                                  79.527                72.340
# Brunei                                  79.240                75.954
# Bulgaria                                78.485                71.618
# Burkina Faso                            61.858                60.350
# Burundi                                 60.262                56.246
# Cambodia                                71.690                67.431
# Cameroon                                60.198                57.965
# ...                                        ...                   ...
# Sudan                                   66.553                63.275
# Suriname                                74.992                68.450
# Swaziland                               61.682                55.421
# Sweden                                  84.443                81.126
# Switzerland                             85.475                81.705
# Syria                                   77.763                66.578
# Tajikistan                              74.531                68.557
# Tanzania                                68.527                65.129
# Thailand                                79.459                72.016
# Timor-Leste                             71.421                67.710
# Togo                                    61.571                59.839
# Tonga                                   76.378                70.291
# Trinidad and Tobago                     74.574                67.447
# Tunisia                                 78.207                74.119
# Turkey                                  79.453                73.020
# Turkmenistan                            71.584                64.603
# Tuvalu                                     NaN                   NaN
# Uganda                                  62.667                58.252
# Ukraine                                 77.067                67.246
# United Arab Emirates                    79.081                76.870
# United Kingdom                          83.558                80.127
# United States                           81.942                77.429
# Uruguay                                 81.126                74.217
# Uzbekistan                              74.362                68.721
# Vanuatu                                 74.869                70.393
# Venezuela                               79.079                70.950
# Vietnam                                 81.203                72.003
# Yemen                                   66.871                63.875
# Zambia                                  65.362                59.845
# Zimbabwe                                63.944                60.120
#
#                        un_accession
# name
# Afghanistan              1946-11-19
# Albania                  1955-12-14
# Algeria                  1962-10-08
# Andorra                  1993-07-28
# Angola                   1976-12-01
# Antigua and Barbuda      1981-11-11
# Argentina                1945-10-24
# Armenia                  1992-03-02
# Australia                1945-11-01
# Austria                  1955-12-14
# Azerbaijan               1992-03-02
# Bahamas                  1973-09-18
# Bahrain                  1971-09-21
# Bangladesh               1974-09-17
# Barbados                 1966-12-09
# Belarus                  1945-10-24
# Belgium                  1945-12-27
# Belize                   1981-09-25
# Benin                    1960-09-20
# Bhutan                   1971-09-21
# Bolivia                  1945-11-14
# Bosnia and Herzegovina   1992-05-22
# Botswana                 1966-10-17
# Brazil                   1945-10-24
# Brunei                   1984-09-21
# Bulgaria                 1955-12-14
# Burkina Faso             1960-09-20
# Burundi                  1962-09-18
# Cambodia                 1955-12-14
# Cameroon                 1960-09-20
# ...                             ...
# Sudan                    1956-11-12
# Suriname                 1975-12-04
# Swaziland                1968-09-24
# Sweden                   1946-11-19
# Switzerland              2002-09-10
# Syria                    1945-10-24
# Tajikistan               1992-03-02
# Tanzania                 1961-12-14
# Thailand                 1946-12-16
# Timor-Leste              2002-09-27
# Togo                     1960-09-20
# Tonga                    1999-09-14
# Trinidad and Tobago      1962-09-18
# Tunisia                  1956-11-12
# Turkey                   1945-10-24
# Turkmenistan             1992-03-02
# Tuvalu                   2000-09-05
# Uganda                   1962-10-25
# Ukraine                  1945-10-24
# United Arab Emirates     1971-12-09
# United Kingdom           1945-10-24
# United States            1945-10-24
# Uruguay                  1945-12-18
# Uzbekistan               1992-03-02
# Vanuatu                  1981-09-15
# Venezuela                1945-11-15
# Vietnam                  1977-09-20
# Yemen                    1947-09-30
# Zambia                   1964-12-01
# Zimbabwe                 1980-08-25
#
# [193 rows x 20 columns]

# %% [markdown]
# Namátkou si vybereme nějakou zemi a podíváme se, jaké údaje o ní v tabulce máme.

# %%
countries.loc["Czechia"]
# Out:
# iso                                             CZE
# world_6region                   europe_central_asia
# world_4region                                europe
# income_groups                           high_income
# is_eu                                          True
# is_oecd                                        True
# eu_accession                             2004-05-01
# year                                           2018
# area                                          78870
# population                                1.059e+07
# alcohol_adults                                16.47
# bmi_men                                       27.91
# bmi_women                                     26.51
# car_deaths_per_100000_people                   5.72
# calories_per_day                               3256
# infant_mortality                                2.8
# life_expectancy                               79.37
# life_expectancy_female                       81.858
# life_expectancy_male                         76.148
# un_accession                             1993-01-19
# Name: Czechia, dtype: object

# %% [markdown]
# Už na první pohled je každé pole jiného typu. Ale jakého? Na to nám odpoví vlastnost `dtypes` naší tabulky (u `Series` použiješ `dtype`, resp. raději `dtype.name`, pokud chceš stejně pěknou řetězcovou reprezentaci).

# %%
countries.dtypes
# Out:
# iso                              object
# world_6region                    object
# world_4region                    object
# income_groups                    object
# is_eu                              bool
# is_oecd                            bool
# eu_accession                     object
# year                              int64
# area                            float64
# population                      float64
# alcohol_adults                  float64
# bmi_men                         float64
# bmi_women                       float64
# car_deaths_per_100000_people    float64
# calories_per_day                float64
# infant_mortality                float64
# life_expectancy                 float64
# life_expectancy_female          float64
# life_expectancy_male            float64
# un_accession                     object
# dtype: object

# %% [markdown]
# Typy v pandas vycházejí z toho, jak je definuje knihovna `numpy` (obecně užitečná pro práci s numerickými poli a poskytující vektorové operace s rychlostí řádově vyšší než v Pythonu jako takovém). Ta potřebuje především vědět, jak alokovat pole pro prvky daného typu - na to, aby mohly být seřazeny efektivně jeden za druhým, a tedy i kolik bajtů paměti každý zabírá. Kopíruje přitom "nativní" datové typy, které už můžeš znát z jiných jazyků, např. [C](https://cs.wikipedia.org/wiki/C_(programovac%C3%AD_jazyk)). Umístění paměti je něco, co v Pythonu obvykle neřešíme, ale rychlé počítání se bez toho neobejde. My nepůjdeme do detailů, ale požadavek na rychlost se nám tu a tam vynoří a my budeme klást důraz na to, aby se operace dělaly "vektorově", řešily "na úrovni numpy".
#
# Poněkud tajuplný systém typů v `numpy` (popsaný v [dokumentaci](https://docs.scipy.org/doc/numpy/user/basics.types.html)) je naštěstí v `pandas` (mírně) zjednodušen a nabízí jen několik užitečných základních (rodin) typů, které si teď představíme.

# %% [markdown]
# ### Celá čísla (integers)
#
# V Pythonu je pro celá čísla vyhrazen přesně jeden typ: `int`, který možňuje pracovat s libovolně velkými celými čísly (0, -58 nebo třeba 123456789012345678901234567890). V `pandas` se můžeš setkat s `int8`, `int16`, `int32`, `int64`, `uint8`, `uint16`, `uint32` a `uint64` - všechny mají stejné základní vlastnosti a každý z nich má jen určitý rozsah čísel, která do něj lze uložit. Liší se velikostí paměti, kterou jedno číslo zabere (číslovka v názvu vyjadřuje počet bitů), a tím, zda jsou podporována i záporná čísla (předpona `u` znamená, že počítáme pouze s nulou a kladnými čísly).
#
# Rozsahy:
#
# - `int8`: -128 až 127
# - `uint8`: 0 až 255
# - `int16`: -32 768 až 32 767
# - `uint16`: 0 až 65 535
# - `int32`: -2 147 483 647 až 2 147 483 647 (tedy +/- ~2 miliardy)
# - `uint32`: 0 až 4 294 967 295 (tedy až ~4 miliardy)
# - `int64`: -9 223 372 036 854 775 808 až 9 223 372 036 854 775 807 (tedy +/- ~9 trilionů)
# - `uint64`: 0 až 18 446 744 073 709 551 615 (tedy až ~18 trilionů)
#
# 💡 Aby toho nebylo málo, ke každému `int?` / `uint?` typu existuje ještě jeho alternativa, která umožňuje ve sloupci použít chybějící hodnoty, t.j. `NaN`. Místo malého `i`, případně `u` v názvu se použije písmeno velké. Tato vlastnost (tzv. "nullable integer types") je relativně užitečná, ale je dosud poněkud experimentální. My ji nebudeme v kurzu využívat.
#
# Detailní vysvětlení toho, jak jsou celá čísla v paměti počítače reprezentována, najdeš třeba ve [wikipedii](https://cs.wikipedia.org/wiki/Integer).

# %% [markdown]
# V `pandas` je výchozí celočíselný typ `int64`, a pokud neřekneš jinak, automaticky se pro celá čísla použije (ve většině případů to bude vhodná volba):

# %%
countries["year"]
# Out:
# name
# Afghanistan               2018
# Albania                   2018
# Algeria                   2018
# Andorra                   2017
# Angola                    2018
# Antigua and Barbuda       2018
# Argentina                 2018
# Armenia                   2018
# Australia                 2018
# Austria                   2018
# Azerbaijan                2018
# Bahamas                   2018
# Bahrain                   2018
# Bangladesh                2018
# Barbados                  2018
# Belarus                   2018
# Belgium                   2018
# Belize                    2018
# Benin                     2018
# Bhutan                    2018
# Bolivia                   2018
# Bosnia and Herzegovina    2018
# Botswana                  2018
# Brazil                    2018
# Brunei                    2018
# Bulgaria                  2018
# Burkina Faso              2018
# Burundi                   2018
# Cambodia                  2018
# Cameroon                  2018
#                           ...
# Sudan                     2018
# Suriname                  2018
# Swaziland                 2018
# Sweden                    2018
# Switzerland               2018
# Syria                     2018
# Tajikistan                2018
# Tanzania                  2018
# Thailand                  2018
# Timor-Leste               2018
# Togo                      2018
# Tonga                     2018
# Trinidad and Tobago       2018
# Tunisia                   2018
# Turkey                    2018
# Turkmenistan              2018
# Tuvalu                    2017
# Uganda                    2018
# Ukraine                   2018
# United Arab Emirates      2018
# United Kingdom            2018
# United States             2018
# Uruguay                   2018
# Uzbekistan                2018
# Vanuatu                   2018
# Venezuela                 2018
# Vietnam                   2018
# Yemen                     2018
# Zambia                    2018
# Zimbabwe                  2018
# Name: year, Length: 193, dtype: int64

# %%
pd.Series([0, 123, 12345])

# pd.Series([0, 123, 12345], dtype="int64")   # totéž
# Out:
# 0        0
# 1      123
# 2    12345
# dtype: int64

# %% [markdown]
# Pomocí argumentu `dtype` můžeš ovšem přesně specifikovat, který typ celých čísel chceš:

# %%
pd.Series([0, 123, 12345], dtype="int16")
# Out:
# 0        0
# 1      123
# 2    12345
# dtype: int16

# %% [markdown]
# **⚠ Pozor:** Když vybíráš konkrétní celočíselný typ, musíš si dát pozor na rozsahy, protože `pandas` tě nebude varovat, pokud se nějaká z tvých hodnot do rozsahu "nevleze" a vesele zahodí tu část binární reprezentace, která je navíc (a dostaneš mnohem menší číslo, než jsi čekal/a):

# %%
pd.Series([0, 123, 12345], dtype="int8")
# Out:
# 0      0
# 1    123
# 2     57
# dtype: int8

# %% [markdown]
# Toto naštěstí neplatí pro typ s nejširším rozsahem (`int64`). Zkusme do něj vložit veliké číslo (třeba 123456789012345678901234567890) a uvidíme, co se stane:

# %%
# Toto vyhodí výjimku:
# pd.Series([0, 123, 123456789012345678901234567890], dtype="int64")

# Toto projde, ale už to není int64:
pd.Series([0, 123, 123456789012345678901234567890])
# Out:
# 0                                 0
# 1                               123
# 2    123456789012345678901234567890
# dtype: object

# %% [markdown]
# - Když ho budeme explicitně požadovat, vyhodí se výjimka.
# - Když `pandas` necháme dělat jeho práci, použije se obecný typ `object` a přijdeme o jistou část výhod: sloupec nám zabere násobně více paměti a aritmetické operace s ním jsou o řád až dva pomalejší. Dokud naší prioritou, není to zase takový problém.
#
# Obecně proto doporučujeme držet se `int64`, resp. nechat `pandas`, aby jej za nás automaticky použil. Teprve v případě, že si to budou žádat přísné paměťové nároky, se ti vyplatí hledat ten "nejvíce růžový" typ.

# %% [markdown]
# **Úkol:** Zkus vytvořit `Series` s datovým typem `uint8`, obsahující (alespoň) jedno malé záporné číslo. Co se stane?

# %% [markdown]
# ### Čísla s plovoucí desetinnou čárkou (floats)
#
# Podobně jako u celočíselných hodnot, i jednomu typu v Python (`float`) odpovídá několik typů v `pandas`: `float16`, `float32`, `float64`. Součástí názvu je opět počet bitů, které jedno číslo potřebuje ke svému uložení. Naštěstí v tomto případě `float64` přesně odpovídá svým chováním `float` z Pythonu, zbylé dva typy nejsou tak přesné a mají menší rozsah - kromě optimalizace paměťových nároků u specifického druhu dat je nejspíš nepoužiješ.
#
# Více teoretického čtení o reprezentaci čísel s desetinnou čárkou najdeš na [wiki](https://cs.wikipedia.org/wiki/Pohybliv%C3%A1_%C5%99%C3%A1dov%C3%A1_%C4%8D%C3%A1rka).

# %%
countries["bmi_men"]
# Out:
# name
# Afghanistan               20.62
# Albania                   26.45
# Algeria                   24.60
# Andorra                   27.63
# Angola                    22.25
# Antigua and Barbuda       25.77
# Argentina                 27.50
# Armenia                   25.36
# Australia                 27.56
# Austria                   26.47
# Azerbaijan                25.65
# Bahamas                   27.25
# Bahrain                   27.84
# Bangladesh                20.40
# Barbados                  26.38
# Belarus                   26.16
# Belgium                   26.76
# Belize                    27.02
# Benin                     22.42
# Bhutan                    22.82
# Bolivia                   24.43
# Bosnia and Herzegovina    26.61
# Botswana                  22.13
# Brazil                    25.79
# Brunei                    24.18
# Bulgaria                  26.54
# Burkina Faso              21.27
# Burundi                   21.50
# Cambodia                  20.80
# Cameroon                  23.68
#                           ...
# Sudan                     22.40
# Suriname                  25.50
# Swaziland                 23.17
# Sweden                    26.38
# Switzerland               26.20
# Syria                     26.92
# Tajikistan                23.78
# Tanzania                  22.48
# Thailand                  23.01
# Timor-Leste               20.59
# Togo                      21.88
# Tonga                     31.00
# Trinidad and Tobago       26.40
# Tunisia                   25.16
# Turkey                    26.70
# Turkmenistan              25.25
# Tuvalu                      NaN
# Uganda                    22.36
# Ukraine                   25.42
# United Arab Emirates      28.05
# United Kingdom            27.39
# United States             28.46
# Uruguay                   26.39
# Uzbekistan                25.32
# Vanuatu                   26.79
# Venezuela                 27.45
# Vietnam                   20.92
# Yemen                     24.44
# Zambia                    20.68
# Zimbabwe                  22.03
# Name: bmi_men, Length: 193, dtype: float64

# %%
# Docela přesné pí
pd.Series([3.14159265])
# Out:
# 0    3.141593
# dtype: float64

# %%
# Ne už tak přesné pí
pd.Series([3.14159265], dtype="float16")
# Out:
# 0    3.140625
# dtype: float16

# %% [markdown]
# **Úkol**: Vytvoř pole typu `float64` jen ze samých celých čísel. Co se stane?

# %% [markdown]
# ### Logické hodnoty (booleans)
#
# Toto je asi nejméně překvapivý datový typ. Chová se v zásadě stejně jako typ `bool` v Pythonu. Nabírá hodnot `True` a `False` (které lze též pokládat za 1 a 0 v některých operacích). Má ještě jednu skvělou vlastnost - objekty `Series` i `DataFrame` jde filtrovat právě pomocí sloupce logického typu (o tom viz níže).

# %%
countries["is_oecd"].iloc[:20]
# Out:
# name
# Afghanistan            False
# Albania                False
# Algeria                False
# Andorra                False
# Angola                 False
# Antigua and Barbuda    False
# Argentina              False
# Armenia                False
# Australia               True
# Austria                 True
# Azerbaijan             False
# Bahamas                False
# Bahrain                False
# Bangladesh             False
# Barbados               False
# Belarus                False
# Belgium                 True
# Belize                 False
# Benin                  False
# Bhutan                 False
# Name: is_oecd, dtype: bool

# %%
# Vytvoření nového sloupce
pd.Series([True, False, False])
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# Jde to ovšem i takto:

# %%
pd.Series([1, 0, 0], dtype="bool")
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# **Úkol:** Co se stane, když vytvoříš `Series` typu `bool` z řetězců `"True"` a `"False"` (nezapomeň na uvozovky)?

# %% [markdown]
# ### Objekty a řetězce (objects)
#
# Toto tě pravděpodobně překvapí: `pandas` nemá zvláštní datový typ pro řetězce! Spadá společně s dalšími neurčenými nebo nerozpoznanými hodnotami do kategorie `object`, která umožňuje v daném sloupci mít cokoliv, co znáš z Pythonu, a chová se tak do značné míry jako obyčejný seznam s výhodami (žádné podivné konverze, sledování rozsahů, ...) i nevýhodami (je to pomalejší, než by mohlo; nikdo ti nezaručí, že ve sloupci budou jen řetězce).
#
# *Poznámka: V době psaní těchto materiálů se připravuje `pandas` verze 1.0, která speciální typ pro řetězce zavádí.*

# %%
countries["iso"]
# Out:
# name
# Afghanistan               AFG
# Albania                   ALB
# Algeria                   DZA
# Andorra                   AND
# Angola                    AGO
# Antigua and Barbuda       ATG
# Argentina                 ARG
# Armenia                   ARM
# Australia                 AUS
# Austria                   AUT
# Azerbaijan                AZE
# Bahamas                   BHS
# Bahrain                   BHR
# Bangladesh                BGD
# Barbados                  BRB
# Belarus                   BLR
# Belgium                   BEL
# Belize                    BLZ
# Benin                     BEN
# Bhutan                    BTN
# Bolivia                   BOL
# Bosnia and Herzegovina    BIH
# Botswana                  BWA
# Brazil                    BRA
# Brunei                    BRN
# Bulgaria                  BGR
# Burkina Faso              BFA
# Burundi                   BDI
# Cambodia                  KHM
# Cameroon                  CMR
#                          ...
# Sudan                     SDN
# Suriname                  SUR
# Swaziland                 SWZ
# Sweden                    SWE
# Switzerland               CHE
# Syria                     SYR
# Tajikistan                TJK
# Tanzania                  TZA
# Thailand                  THA
# Timor-Leste               TLS
# Togo                      TGO
# Tonga                     TON
# Trinidad and Tobago       TTO
# Tunisia                   TUN
# Turkey                    TUR
# Turkmenistan              TKM
# Tuvalu                    TUV
# Uganda                    UGA
# Ukraine                   UKR
# United Arab Emirates      ARE
# United Kingdom            GBR
# United States             USA
# Uruguay                   URY
# Uzbekistan                UZB
# Vanuatu                   VUT
# Venezuela                 VEN
# Vietnam                   VNM
# Yemen                     YEM
# Zambia                    ZMB
# Zimbabwe                  ZWE
# Name: iso, Length: 193, dtype: object

# %%
# Domácí mazlíčci
pd.Series(["pes", "kočka", "křeček", "tarantule", "hroznýš"])
# Out:
# 0          pes
# 1        kočka
# 2       křeček
# 3    tarantule
# 4      hroznýš
# dtype: object

# %%
pd.Series([1, "dvě", 3.0])   # Řetězec a další "smetí"
# Out:
# 0      1
# 1    dvě
# 2      3
# dtype: object

# %% [markdown]
# Pozor, třeba i takový seznam může být hodnotou v sloupci typu `object`:

# %%
# Objednávky
pd.Series(
    [["řízek", "brambory", "cola"], ["smažák", "hranolky"], ["sodovka"]],
    index=["Eva", "Evelína", "Evženie"])
# Out:
# Eva        [řízek, brambory, cola]
# Evelína         [smažák, hranolky]
# Evženie                  [sodovka]
# dtype: object

# %% [markdown]
# **Úkol:** Co za druh objektu (a jaký `dtype`) dostaneme, když se pokusíme získat jeden řádek z tabulky `planety`?

# %% [markdown]
# ### Datum / čas (datetime)
#
# Časovými daty se blíže zabývá jedna z následujících lekcí, nicméně nějaká v tabulce zemí už máme, a tak alespoň pro úplnost uvedeme, co v tomto směru `pandas` nabízí:
#
# - Časové či datumové údaje (*datetime*) jakožto body na časové ose.
#
# - Časové údaje s označením časové zóny (*datetimes with time zone*).
#
# - Časové úseky (*timedeltas*) jakožto určení délky nějakého úseku (počítáno v nanosekundách)
#
# - Období (*periods*) udávají nějak určená časová období (třeba "únor 2020")

# %% [markdown]
# 💡 Pro převod z nejrůznějších formátů na datum / čas slouží funkce `to_datetime`, kterou použijeme pro následující ukázku:

# %%
pd.to_datetime(countries["un_accession"])
# Out:
# name
# Afghanistan              1946-11-19
# Albania                  1955-12-14
# Algeria                  1962-10-08
# Andorra                  1993-07-28
# Angola                   1976-12-01
# Antigua and Barbuda      1981-11-11
# Argentina                1945-10-24
# Armenia                  1992-03-02
# Australia                1945-11-01
# Austria                  1955-12-14
# Azerbaijan               1992-03-02
# Bahamas                  1973-09-18
# Bahrain                  1971-09-21
# Bangladesh               1974-09-17
# Barbados                 1966-12-09
# Belarus                  1945-10-24
# Belgium                  1945-12-27
# Belize                   1981-09-25
# Benin                    1960-09-20
# Bhutan                   1971-09-21
# Bolivia                  1945-11-14
# Bosnia and Herzegovina   1992-05-22
# Botswana                 1966-10-17
# Brazil                   1945-10-24
# Brunei                   1984-09-21
# Bulgaria                 1955-12-14
# Burkina Faso             1960-09-20
# Burundi                  1962-09-18
# Cambodia                 1955-12-14
# Cameroon                 1960-09-20
#                             ...
# Sudan                    1956-11-12
# Suriname                 1975-12-04
# Swaziland                1968-09-24
# Sweden                   1946-11-19
# Switzerland              2002-09-10
# Syria                    1945-10-24
# Tajikistan               1992-03-02
# Tanzania                 1961-12-14
# Thailand                 1946-12-16
# Timor-Leste              2002-09-27
# Togo                     1960-09-20
# Tonga                    1999-09-14
# Trinidad and Tobago      1962-09-18
# Tunisia                  1956-11-12
# Turkey                   1945-10-24
# Turkmenistan             1992-03-02
# Tuvalu                   2000-09-05
# Uganda                   1962-10-25
# Ukraine                  1945-10-24
# United Arab Emirates     1971-12-09
# United Kingdom           1945-10-24
# United States            1945-10-24
# Uruguay                  1945-12-18
# Uzbekistan               1992-03-02
# Vanuatu                  1981-09-15
# Venezuela                1945-11-15
# Vietnam                  1977-09-20
# Yemen                    1947-09-30
# Zambia                   1964-12-01
# Zimbabwe                 1980-08-25
# Name: un_accession, Length: 193, dtype: datetime64[ns]

# %% [markdown]
# ### Kategorické (category)
#
# Pokud chceme být efektivní při práci se sloupci, kde se často opakují hodnoty (zejména řetězcové), můžeme je zakódovat do kategorií. Tím mnohdy ušetříme zabrané místo a urychlíme některé operace. Při takové konverzi `pandas` najde všechny unikátní hodnoty v daném sloupci, uloží si je do zvláštního seznamu a do sloupce uloží jenom indexy z tohoto seznamu. Vše se chová transparentně a při používání tak většinou ani nepoznáte, jestli máte sloupec typu `object` nebo `category`.

# %% [markdown]
# 💡 Pro převod mezi různými datovými typy slouží metoda `astype`, která jako svůj argument akceptuje jméno dtype, na který chceme převést:

# %%
countries["income_groups"].astype("category")
# Out:
# name
# Afghanistan                        low_income
# Albania                   upper_middle_income
# Algeria                   upper_middle_income
# Andorra                           high_income
# Angola                    upper_middle_income
# Antigua and Barbuda               high_income
# Argentina                 upper_middle_income
# Armenia                   lower_middle_income
# Australia                         high_income
# Austria                           high_income
# Azerbaijan                upper_middle_income
# Bahamas                           high_income
# Bahrain                           high_income
# Bangladesh                         low_income
# Barbados                          high_income
# Belarus                   upper_middle_income
# Belgium                           high_income
# Belize                    upper_middle_income
# Benin                              low_income
# Bhutan                    lower_middle_income
# Bolivia                   lower_middle_income
# Bosnia and Herzegovina    upper_middle_income
# Botswana                  upper_middle_income
# Brazil                    upper_middle_income
# Brunei                            high_income
# Bulgaria                  upper_middle_income
# Burkina Faso                       low_income
# Burundi                            low_income
# Cambodia                           low_income
# Cameroon                  lower_middle_income
#                                  ...
# Sudan                     lower_middle_income
# Suriname                  upper_middle_income
# Swaziland                 lower_middle_income
# Sweden                            high_income
# Switzerland                       high_income
# Syria                     lower_middle_income
# Tajikistan                         low_income
# Tanzania                           low_income
# Thailand                  upper_middle_income
# Timor-Leste               lower_middle_income
# Togo                               low_income
# Tonga                     upper_middle_income
# Trinidad and Tobago               high_income
# Tunisia                   upper_middle_income
# Turkey                    upper_middle_income
# Turkmenistan              upper_middle_income
# Tuvalu                    upper_middle_income
# Uganda                             low_income
# Ukraine                   lower_middle_income
# United Arab Emirates              high_income
# United Kingdom                    high_income
# United States                     high_income
# Uruguay                           high_income
# Uzbekistan                lower_middle_income
# Vanuatu                   lower_middle_income
# Venezuela                 upper_middle_income
# Vietnam                   lower_middle_income
# Yemen                     lower_middle_income
# Zambia                    lower_middle_income
# Zimbabwe                           low_income
# Name: income_groups, Length: 193, dtype: category
# Categories (4, object): [high_income, low_income, lower_middle_income, upper_middle_income]

# %% [markdown]
# **Úkol:** Napadne tě, které sloupce z tabulky `countries` bychom měli překonvertovat na nějaký jiný typ?

# %% [markdown]
# ## Matematika
#
# Počítání se `Series` v `pandas` je navrženo tak, aby co nejméně překvapilo. Jednotlivé sloupce se tak můžou stát součástí aritmetických výrazů společně se skalárními hodnotami, s jinými sloupci, `numpy` poli příslušného tvaru, a dokonce i seznamy.

# %%
# Očekávaná doba života ve dnech
countries["life_expectancy"] * 365
# Out:
# name
# Afghanistan               21421.85
# Albania                   28473.65
# Algeria                   28418.90
# Andorra                   30130.75
# Angola                    23794.35
# Antigua and Barbuda       28324.00
# Argentina                 28094.05
# Armenia                   27729.05
# Australia                 30247.55
# Austria                   29871.60
# Azerbaijan                26389.50
# Bahamas                   27046.50
# Bahrain                   28170.70
# Bangladesh                26794.65
# Barbados                  28046.60
# Belarus                   26922.40
# Belgium                   29648.95
# Belize                    26444.25
# Benin                     23717.70
# Bhutan                    27312.95
# Bolivia                   26999.05
# Bosnia and Herzegovina    28444.45
# Botswana                  24425.80
# Brazil                    27630.50
# Brunei                    28236.40
# Bulgaria                  27491.80
# Burkina Faso              22484.00
# Burundi                   22316.10
# Cambodia                  25312.75
# Cameroon                  22345.30
#                             ...
# Sudan                     25101.05
# Suriname                  26141.30
# Swaziland                 21403.60
# Sweden                    30065.05
# Switzerland               30459.25
# Syria                     25484.30
# Tajikistan                26349.35
# Tanzania                  23892.90
# Thailand                  28524.75
# Timor-Leste               26769.10
# Togo                      23027.85
# Tonga                     25805.50
# Trinidad and Tobago       26780.05
# Tunisia                   28455.40
# Turkey                    29057.65
# Turkmenistan              25725.20
# Tuvalu                         NaN
# Uganda                    22943.90
# Ukraine                   26385.85
# United Arab Emirates      28064.85
# United Kingdom            29634.35
# United States             28886.10
# Uruguay                   28313.05
# Uzbekistan                25732.50
# Vanuatu                   23469.50
# Venezuela                 27707.15
# Vietnam                   27331.20
# Yemen                     24506.10
# Zambia                    21699.25
# Zimbabwe                  21965.70
# Name: life_expectancy, Length: 193, dtype: float64

# %%
# Hustota obyvatelstva
countries["population"] / countries["area"]
# Out:
# name
# Afghanistan                 52.844408
# Albania                    112.626087
# Algeria                     15.526464
# Andorra                    189.170213
# Angola                      16.611855
# Antigua and Barbuda        207.727273
# Argentina                   14.915120
# Armenia                    104.841964
# Australia                    2.998235
# Austria                    100.633055
# Azerbaijan                 110.080831
# Bahamas                     25.590778
# Bahrain                   1785.992218
# Bangladesh                1045.857888
# Barbados                   639.767442
# Belarus                     45.751445
# Belgium                    354.405503
# Belize                      14.397040
# Benin                       83.713838
# Bhutan                      19.854665
# Bolivia                      9.475869
# Bosnia and Herzegovina      72.954501
# Botswana                     3.566947
# Brazil                      23.497582
# Brunei                      72.755633
# Bulgaria                    66.207207
# Burkina Faso                65.677193
# Burundi                    320.194035
# Cambodia                    80.976580
# Cameroon                    43.980313
#                              ...
# Sudan                       19.123557
# Suriname                     3.289586
# Swaziland                   71.255760
# Sweden                      21.335658
# Switzerland                187.987406
# Syria                      115.941246
# Tajikistan                  50.814848
# Tanzania                    51.884303
# Thailand                   136.888057
# Timor-Leste                 82.313383
# Togo                       112.924811
# Tonga                      140.400000
# Trinidad and Tobago        264.132554
# Tunisia                     66.071756
# Turkey                      95.957217
# Turkmenistan                10.725261
# Tuvalu                     329.600000
# Uganda                     152.183813
# Ukraine                     74.061801
# United Arab Emirates        98.181818
# United Kingdom             259.348959
# United States               32.395837
# Uruguay                     19.311088
# Uzbekistan                  63.477872
# Vanuatu                     21.148482
# Venezuela                   33.265720
# Vietnam                    273.924591
# Yemen                       49.927079
# Zambia                      19.013832
# Zimbabwe                    34.113011
# Length: 193, dtype: float64

# %%
# Jak nám zdražili obědy
pd.Series([109, 99], index=["řízek", "smažák"]) + [20.9, 10.9]   # sčítání se seznamem
# Out:
# řízek     129.9
# smažák    109.9
# dtype: float64

# %% [markdown]
# **Úkol**: Spočti celkový počet mrtvých v automobilových haváriích v jednotlivých zemích (použij sloupce "population" a  "car_deaths_per_100000_people" a jednoduchou aritmetiku). Sedí výsledek pro ČR?

# %%
# Jak dlouho jsou v OSN?
from datetime import datetime
datetime.now() - pd.to_datetime(countries["un_accession"])
# Out:
# name
# Afghanistan              26721 days 18:19:55.905858
# Albania                  23409 days 18:19:55.905858
# Algeria                  20919 days 18:19:55.905858
# Andorra                   9668 days 18:19:55.905858
# Angola                   15751 days 18:19:55.905858
# Antigua and Barbuda      13945 days 18:19:55.905858
# Argentina                27112 days 18:19:55.905858
# Armenia                  10181 days 18:19:55.905858
# Australia                27104 days 18:19:55.905858
# Austria                  23409 days 18:19:55.905858
# Azerbaijan               10181 days 18:19:55.905858
# Bahamas                  16921 days 18:19:55.905858
# Bahrain                  17649 days 18:19:55.905858
# Bangladesh               16557 days 18:19:55.905858
# Barbados                 19396 days 18:19:55.905858
# Belarus                  27112 days 18:19:55.905858
# Belgium                  27048 days 18:19:55.905858
# Belize                   13992 days 18:19:55.905858
# Benin                    21667 days 18:19:55.905858
# Bhutan                   17649 days 18:19:55.905858
# Bolivia                  27091 days 18:19:55.905858
# Bosnia and Herzegovina   10100 days 18:19:55.905858
# Botswana                 19449 days 18:19:55.905858
# Brazil                   27112 days 18:19:55.905858
# Brunei                   12900 days 18:19:55.905858
# Bulgaria                 23409 days 18:19:55.905858
# Burkina Faso             21667 days 18:19:55.905858
# Burundi                  20939 days 18:19:55.905858
# Cambodia                 23409 days 18:19:55.905858
# Cameroon                 21667 days 18:19:55.905858
#                                     ...
# Sudan                    23075 days 18:19:55.905858
# Suriname                 16114 days 18:19:55.905858
# Swaziland                18741 days 18:19:55.905858
# Sweden                   26721 days 18:19:55.905858
# Switzerland               6337 days 18:19:55.905858
# Syria                    27112 days 18:19:55.905858
# Tajikistan               10181 days 18:19:55.905858
# Tanzania                 21217 days 18:19:55.905858
# Thailand                 26694 days 18:19:55.905858
# Timor-Leste               6320 days 18:19:55.905858
# Togo                     21667 days 18:19:55.905858
# Tonga                     7429 days 18:19:55.905858
# Trinidad and Tobago      20939 days 18:19:55.905858
# Tunisia                  23075 days 18:19:55.905858
# Turkey                   27112 days 18:19:55.905858
# Turkmenistan             10181 days 18:19:55.905858
# Tuvalu                    7072 days 18:19:55.905858
# Uganda                   20902 days 18:19:55.905858
# Ukraine                  27112 days 18:19:55.905858
# United Arab Emirates     17570 days 18:19:55.905858
# United Kingdom           27112 days 18:19:55.905858
# United States            27112 days 18:19:55.905858
# Uruguay                  27057 days 18:19:55.905858
# Uzbekistan               10181 days 18:19:55.905858
# Vanuatu                  14002 days 18:19:55.905858
# Venezuela                27090 days 18:19:55.905858
# Vietnam                  15458 days 18:19:55.905858
# Yemen                    26406 days 18:19:55.905858
# Zambia                   20134 days 18:19:55.905858
# Zimbabwe                 14388 days 18:19:55.905858
# Name: un_accession, Length: 193, dtype: timedelta64[ns]

# %% [markdown]
# 💡 Čísla s plouvoucí desetinnou čárkou mohou obsahovat i speciální hodnoty "not a number" a plus nebo mínus nekonečno. Vzniknou např. při nevhodném dělení nulou:

# %%
pd.Series([0, -1, 1]) / pd.Series([0, 0, 0])
# Out:
# 0    NaN
# 1   -inf
# 2    inf
# dtype: float64

# %% [markdown]
# **Varování:** Nabádáme tě k opatrnosti při práci s omezenými celočíselnými typy. Podobně jako při jejich nevhodné konverzi, i tady může výsledek "přetéct" a ukazovat pochybné výsledky. O důvod víc, proč se držet `int64`.

# %%
pd.Series([7, 14, 149], dtype="int8") * 2
# Out:
# 0    14
# 1    28
# 2    42
# dtype: int8

# %% [markdown]
# ## Porovnávání

# %% [markdown]
# Pro `Series` lze použít nejen operátory početní, ale také logické. Výsledkem pak není jedna logická hodnota, ale sloupec logických hodnot.

# %%
# 15 litrů čistého alkoholu na osobu na rok budeme považovat za hranici nadměrného pití
# (nekonzultováno s adiktology!)

# Kde se hodně pije?
countries["alcohol_adults"] > 15
# Out:
# name
# Afghanistan               False
# Albania                   False
# Algeria                   False
# Andorra                   False
# Angola                    False
# Antigua and Barbuda       False
# Argentina                 False
# Armenia                   False
# Australia                 False
# Austria                   False
# Azerbaijan                False
# Bahamas                   False
# Bahrain                   False
# Bangladesh                False
# Barbados                  False
# Belarus                    True
# Belgium                   False
# Belize                    False
# Benin                     False
# Bhutan                    False
# Bolivia                   False
# Bosnia and Herzegovina    False
# Botswana                  False
# Brazil                    False
# Brunei                    False
# Bulgaria                  False
# Burkina Faso              False
# Burundi                   False
# Cambodia                  False
# Cameroon                  False
#                           ...
# Sudan                     False
# Suriname                  False
# Swaziland                 False
# Sweden                    False
# Switzerland               False
# Syria                     False
# Tajikistan                False
# Tanzania                  False
# Thailand                  False
# Timor-Leste               False
# Togo                      False
# Tonga                     False
# Trinidad and Tobago       False
# Tunisia                   False
# Turkey                    False
# Turkmenistan              False
# Tuvalu                    False
# Uganda                     True
# Ukraine                    True
# United Arab Emirates      False
# United Kingdom            False
# United States             False
# Uruguay                   False
# Uzbekistan                False
# Vanuatu                   False
# Venezuela                 False
# Vietnam                   False
# Yemen                     False
# Zambia                    False
# Zimbabwe                  False
# Name: alcohol_adults, Length: 193, dtype: bool

# %%
# Skoro nikde. A jak jsme na tom u nás?
(countries["alcohol_adults"] > 15).loc["Czechia"]
# Out:
# True

# %%
# Jsou muži v jednotlivých zemích tlustší než ženy?
countries["bmi_men"] > countries["bmi_women"]
# Out:
# name
# Afghanistan               False
# Albania                    True
# Algeria                   False
# Andorra                    True
# Angola                    False
# Antigua and Barbuda       False
# Argentina                  True
# Armenia                   False
# Australia                  True
# Austria                    True
# Azerbaijan                False
# Bahamas                   False
# Bahrain                   False
# Bangladesh                False
# Barbados                  False
# Belarus                   False
# Belgium                    True
# Belize                    False
# Benin                     False
# Bhutan                    False
# Bolivia                   False
# Bosnia and Herzegovina     True
# Botswana                  False
# Brazil                    False
# Brunei                     True
# Bulgaria                   True
# Burkina Faso              False
# Burundi                    True
# Cambodia                  False
# Cameroon                  False
#                           ...
# Sudan                     False
# Suriname                  False
# Swaziland                 False
# Sweden                     True
# Switzerland                True
# Syria                     False
# Tajikistan                False
# Tanzania                  False
# Thailand                  False
# Timor-Leste               False
# Togo                      False
# Tonga                     False
# Trinidad and Tobago       False
# Tunisia                   False
# Turkey                    False
# Turkmenistan               True
# Tuvalu                    False
# Uganda                    False
# Ukraine                   False
# United Arab Emirates      False
# United Kingdom             True
# United States              True
# Uruguay                   False
# Uzbekistan                False
# Vanuatu                   False
# Venezuela                 False
# Vietnam                   False
# Yemen                     False
# Zambia                    False
# Zimbabwe                  False
# Length: 193, dtype: bool

# %% [markdown]
# **Úkol**: Zjistěte, jestli se v jednotlivých zemích dožívají více muži nebo ženy.

# %%
# Leží země v Africe?
countries["world_4region"] == "africa"
# Out:
# name
# Afghanistan               False
# Albania                   False
# Algeria                    True
# Andorra                   False
# Angola                     True
# Antigua and Barbuda       False
# Argentina                 False
# Armenia                   False
# Australia                 False
# Austria                   False
# Azerbaijan                False
# Bahamas                   False
# Bahrain                   False
# Bangladesh                False
# Barbados                  False
# Belarus                   False
# Belgium                   False
# Belize                    False
# Benin                      True
# Bhutan                    False
# Bolivia                   False
# Bosnia and Herzegovina    False
# Botswana                   True
# Brazil                    False
# Brunei                    False
# Bulgaria                  False
# Burkina Faso               True
# Burundi                    True
# Cambodia                  False
# Cameroon                   True
#                           ...
# Sudan                      True
# Suriname                  False
# Swaziland                  True
# Sweden                    False
# Switzerland               False
# Syria                     False
# Tajikistan                False
# Tanzania                   True
# Thailand                  False
# Timor-Leste               False
# Togo                       True
# Tonga                     False
# Trinidad and Tobago       False
# Tunisia                    True
# Turkey                    False
# Turkmenistan              False
# Tuvalu                    False
# Uganda                     True
# Ukraine                   False
# United Arab Emirates      False
# United Kingdom            False
# United States             False
# Uruguay                   False
# Uzbekistan                False
# Vanuatu                   False
# Venezuela                 False
# Vietnam                   False
# Yemen                     False
# Zambia                     True
# Zimbabwe                   True
# Name: world_4region, Length: 193, dtype: bool

# %% [markdown]
# Podobně jako v Pythonu lze podmínky kombinovat pomocí operátorů. Vzhledem k jistým syntaktickým požadavkům Pythonu je ale potřeba použít místo vám známých logických operátorů jejich alternativy: `&` (místo `and`), `|` (místo `or`) a `~` (místo `not`). Protože mají jiné priority než jejich klasičtí bratříčci, bude lepší, když při kombinaci s jinými operátory vždycky použiješ závorky.

# %%
# Kde se ženy i muži dožívají přes 75 let?
(countries["life_expectancy_male"] > 75) & (countries["life_expectancy_female"] > 75)
# Out:
# name
# Afghanistan               False
# Albania                    True
# Algeria                    True
# Andorra                   False
# Angola                    False
# Antigua and Barbuda       False
# Argentina                 False
# Armenia                   False
# Australia                  True
# Austria                    True
# Azerbaijan                False
# Bahamas                   False
# Bahrain                    True
# Bangladesh                False
# Barbados                  False
# Belarus                   False
# Belgium                    True
# Belize                    False
# Benin                     False
# Bhutan                    False
# Bolivia                   False
# Bosnia and Herzegovina    False
# Botswana                  False
# Brazil                    False
# Brunei                     True
# Bulgaria                  False
# Burkina Faso              False
# Burundi                   False
# Cambodia                  False
# Cameroon                  False
#                           ...
# Sudan                     False
# Suriname                  False
# Swaziland                 False
# Sweden                     True
# Switzerland                True
# Syria                     False
# Tajikistan                False
# Tanzania                  False
# Thailand                  False
# Timor-Leste               False
# Togo                      False
# Tonga                     False
# Trinidad and Tobago       False
# Tunisia                   False
# Turkey                    False
# Turkmenistan              False
# Tuvalu                    False
# Uganda                    False
# Ukraine                   False
# United Arab Emirates       True
# United Kingdom             True
# United States              True
# Uruguay                   False
# Uzbekistan                False
# Vanuatu                   False
# Venezuela                 False
# Vietnam                   False
# Yemen                     False
# Zambia                    False
# Zimbabwe                  False
# Length: 193, dtype: bool

# %% [markdown]
# ## Filtrování
#
# Pokud chceš z tabulky vybrat řádky, které splňují nějaké kritérium, musíš (není to vždy těžké :-)) toto kritérium převést do podoby sloupce logických hodnot. Potom tento sloupec (sloupec samotný, nikoliv jeho název!) vložíš do hranatých závorek jako index `DataFrame`.
#
# Když budeš například chtít informace jen o členech EU, můžeš k tomu přímo použít sloupec "is_eu", který logické hodnoty obsahuje:

# %%
countries[countries["is_eu"]]
# Out:
#                 iso        world_6region world_4region        income_groups  \
# name
# Austria         AUT  europe_central_asia        europe          high_income
# Belgium         BEL  europe_central_asia        europe          high_income
# Bulgaria        BGR  europe_central_asia        europe  upper_middle_income
# Croatia         HRV  europe_central_asia        europe          high_income
# Cyprus          CYP  europe_central_asia        europe          high_income
# Czechia         CZE  europe_central_asia        europe          high_income
# Denmark         DNK  europe_central_asia        europe          high_income
# Estonia         EST  europe_central_asia        europe          high_income
# Finland         FIN  europe_central_asia        europe          high_income
# France          FRA  europe_central_asia        europe          high_income
# Germany         DEU  europe_central_asia        europe          high_income
# Greece          GRC  europe_central_asia        europe          high_income
# Hungary         HUN  europe_central_asia        europe  upper_middle_income
# Ireland         IRL  europe_central_asia        europe          high_income
# Italy           ITA  europe_central_asia        europe          high_income
# Latvia          LVA  europe_central_asia        europe          high_income
# Lithuania       LTU  europe_central_asia        europe          high_income
# Luxembourg      LUX  europe_central_asia        europe          high_income
# Malta           MLT  europe_central_asia        europe          high_income
# Netherlands     NLD  europe_central_asia        europe          high_income
# Poland          POL  europe_central_asia        europe          high_income
# Portugal        PRT  europe_central_asia        europe          high_income
# Romania         ROU  europe_central_asia        europe  upper_middle_income
# Slovakia        SVK  europe_central_asia        europe          high_income
# Slovenia        SVN  europe_central_asia        europe          high_income
# Spain           ESP  europe_central_asia        europe          high_income
# Sweden          SWE  europe_central_asia        europe          high_income
# United Kingdom  GBR  europe_central_asia        europe          high_income
#
#                 is_eu  is_oecd eu_accession  year      area  population  \
# name
# Austria          True     True   1995-01-01  2018   83879.0   8441000.0
# Belgium          True     True   1952-07-23  2018   30530.0  10820000.0
# Bulgaria         True    False   2007-01-01  2018  111000.0   7349000.0
# Croatia          True    False   2013-01-01  2018   56590.0   4379000.0
# Cyprus           True    False   2004-05-01  2018    9250.0   1141000.0
# Czechia          True     True   2004-05-01  2018   78870.0  10590000.0
# Denmark          True     True   1973-01-01  2018   42922.0   5611000.0
# Estonia          True     True   2004-05-01  2018   45230.0   1339000.0
# Finland          True     True   1995-01-01  2018  338420.0   5419000.0
# France           True     True   1952-07-23  2018  549087.0  63780000.0
# Germany          True     True   1952-07-23  2018  357380.0  81800000.0
# Greece           True     True   1981-01-01  2018  131960.0  11450000.0
# Hungary          True     True   2004-05-01  2018   93030.0   9934000.0
# Ireland          True     True   1973-01-01  2018   70280.0   4631000.0
# Italy            True     True   1952-07-23  2018  301340.0  61090000.0
# Latvia           True     True   2004-05-01  2018   64490.0   2226000.0
# Lithuania        True     True   2004-05-01  2018   65286.0   3278000.0
# Luxembourg       True     True   1952-07-23  2018    2590.0    530000.0
# Malta            True    False   2004-05-01  2018     320.0    420600.0
# Netherlands      True     True   1952-07-23  2018   41540.0  16760000.0
# Poland           True     True   2004-05-01  2018  312680.0  38330000.0
# Portugal         True     True   1986-01-01  2018   92225.0  10700000.0
# Romania          True    False   2007-01-01  2018  238390.0  21340000.0
# Slovakia         True     True   2004-05-01  2018   49035.0   5489000.0
# Slovenia         True     True   2004-05-01  2018   20270.0   2045000.0
# Spain            True     True   1986-01-01  2018  505940.0  47040000.0
# Sweden           True     True   1995-01-01  2018  447420.0   9546000.0
# United Kingdom   True     True   1973-01-01  2018  243610.0  63180000.0
#
#                 alcohol_adults  bmi_men  bmi_women  \
# name
# Austria                  12.40    26.47      25.09
# Belgium                  10.41    26.76      25.14
# Bulgaria                 11.40    26.54      25.52
# Croatia                  15.00    26.60      25.18
# Cyprus                    8.84    27.42      25.93
# Czechia                  16.47    27.91      26.51
# Denmark                  12.02    26.13      25.11
# Estonia                  17.24    26.26      25.19
# Finland                  13.10    26.73      25.58
# France                   12.48    25.85      24.83
# Germany                  12.14    27.17      25.74
# Greece                   11.01    26.34      24.92
# Hungary                  16.12    27.12      25.98
# Ireland                  14.92    27.65      26.62
# Italy                     9.72    26.48      24.79
# Latvia                   13.45    26.46      25.62
# Lithuania                16.30    26.86      26.01
# Luxembourg               12.84    27.43      26.09
# Malta                     4.10    27.68      27.05
# Netherlands               9.75    26.02      25.47
# Poland                   14.43    26.67      25.92
# Portugal                 13.89    26.68      26.18
# Romania                  16.15    25.41      25.22
# Slovakia                 13.31    26.93      26.32
# Slovenia                 14.94    27.44      26.58
# Spain                    11.83    27.50      26.31
# Sweden                    9.50    26.38      25.15
# United Kingdom           13.24    27.39      26.94
#
#                 car_deaths_per_100000_people  calories_per_day  \
# name
# Austria                                3.541            3768.0
# Belgium                                5.427            3733.0
# Bulgaria                               9.662            2829.0
# Croatia                                6.434            3059.0
# Cyprus                                 6.419            2649.0
# Czechia                                5.720            3256.0
# Denmark                                3.481            3367.0
# Estonia                                5.896            3253.0
# Finland                                3.615            3368.0
# France                                 2.491            3482.0
# Germany                                3.280            3499.0
# Greece                                 9.175            3400.0
# Hungary                                5.234            3037.0
# Ireland                                3.768            3600.0
# Italy                                  3.778            3579.0
# Latvia                                 8.275            3174.0
# Lithuania                              8.090            3417.0
# Luxembourg                             5.971            3539.0
# Malta                                  2.228            3378.0
# Netherlands                            2.237            3228.0
# Poland                                 7.675            3451.0
# Portugal                               5.078            3477.0
# Romania                                8.808            3358.0
# Slovakia                               6.746            2944.0
# Slovenia                               5.315            3168.0
# Spain                                  5.146            3174.0
# Sweden                                 2.737            3179.0
# United Kingdom                         3.377            3424.0
#
#                 infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Austria                      2.9            81.84                  84.249
# Belgium                      3.3            81.23                  83.751
# Bulgaria                     9.3            75.32                  78.485
# Croatia                      3.6            77.66                  81.167
# Cyprus                       2.5            80.79                  82.918
# Czechia                      2.8            79.37                  81.858
# Denmark                      2.9            81.10                  82.878
# Estonia                      2.3            77.66                  82.111
# Finland                      1.9            82.06                  84.423
# France                       3.5            82.62                  85.747
# Germany                      3.1            81.25                  83.632
# Greece                       3.6            81.34                  84.071
# Hungary                      5.3            75.90                  79.557
# Ireland                      3.0            81.49                  83.737
# Italy                        2.9            82.62                  85.435
# Latvia                       6.9            75.13                  79.498
# Lithuania                    3.3            75.31                  80.060
# Luxembourg                   1.5            82.39                  84.227
# Malta                        5.1            81.75                  82.724
# Netherlands                  3.2            81.92                  83.841
# Poland                       4.5            78.19                  81.732
# Portugal                     3.0            81.30                  84.372
# Romania                      9.7            75.53                  79.158
# Slovakia                     5.8            77.16                  80.511
# Slovenia                     2.1            81.12                  84.017
# Spain                        3.5            83.23                  86.119
# Sweden                       2.4            82.37                  84.443
# United Kingdom               3.5            81.19                  83.558
#
#                 life_expectancy_male un_accession
# name
# Austria                       79.585   1955-12-14
# Belgium                       79.131   1945-12-27
# Bulgaria                      71.618   1955-12-14
# Croatia                       74.701   1992-05-22
# Cyprus                        78.734   1960-09-20
# Czechia                       76.148   1993-01-19
# Denmark                       79.130   1945-10-24
# Estonia                       73.201   1991-09-17
# Finland                       78.934   1955-12-14
# France                        79.991   1945-10-24
# Germany                       79.060   1973-09-18
# Greece                        79.129   1945-10-25
# Hungary                       72.610   1955-12-14
# Ireland                       79.885   1955-12-14
# Italy                         81.146   1955-12-14
# Latvia                        69.882   1991-09-17
# Lithuania                     69.554   1991-09-17
# Luxembourg                    79.981   1945-10-24
# Malta                         79.570   1964-12-01
# Netherlands                   80.440   1945-12-10
# Poland                        74.043   1945-10-24
# Portugal                      78.685   1955-12-14
# Romania                       72.265   1955-12-14
# Slovakia                      73.589   1993-01-19
# Slovenia                      78.499   1992-05-22
# Spain                         80.694   1955-12-14
# Sweden                        81.126   1946-11-19
# United Kingdom                80.127   1945-10-24

# %% [markdown]
# Nemusíš použít existující sloupec v tabulce, ale i jakoukoliv vypočítanou hodnotu stejného tvaru:

# %%
# Prťavé země
countries[countries["population"] < 100_000]   # Podtržítko pomáhá oddělit tisíce vizuálně
# Out:
#                        iso        world_6region world_4region  \
# name
# Andorra                AND  europe_central_asia        europe
# Antigua and Barbuda    ATG              america      americas
# Dominica               DMA              america      americas
# Liechtenstein          LIE  europe_central_asia        europe
# Marshall Islands       MHL    east_asia_pacific          asia
# Monaco                 MCO  europe_central_asia        europe
# Nauru                  NRU    east_asia_pacific          asia
# Palau                  PLW    east_asia_pacific          asia
# Saint Kitts and Nevis  KNA              america      americas
# San Marino             SMR  europe_central_asia        europe
# Seychelles             SYC   sub_saharan_africa        africa
# Tuvalu                 TUV    east_asia_pacific          asia
#
#                              income_groups  is_eu  is_oecd eu_accession  year  \
# name
# Andorra                        high_income  False    False          NaN  2017
# Antigua and Barbuda            high_income  False    False          NaN  2018
# Dominica               upper_middle_income  False    False          NaN  2017
# Liechtenstein                  high_income  False    False          NaN  2017
# Marshall Islands       upper_middle_income  False    False          NaN  2017
# Monaco                         high_income  False    False          NaN  2017
# Nauru                                  NaN  False    False          NaN  2015
# Palau                  upper_middle_income  False    False          NaN  2017
# Saint Kitts and Nevis          high_income  False    False          NaN  2017
# San Marino                     high_income  False    False          NaN  2017
# Seychelles             upper_middle_income  False    False          NaN  2018
# Tuvalu                 upper_middle_income  False    False          NaN  2017
#
#                         area  population  alcohol_adults  bmi_men  bmi_women  \
# name
# Andorra                470.0     88910.0           10.17    27.63      26.43
# Antigua and Barbuda    440.0     91400.0            8.17    25.77      27.51
# Dominica               750.0     67700.0            8.68    24.57      28.78
# Liechtenstein          160.0     36870.0             NaN      NaN        NaN
# Marshall Islands       180.0     56690.0             NaN    29.37      31.39
# Monaco                   2.0     35460.0             NaN      NaN        NaN
# Nauru                   20.0     10440.0            4.81    33.90      35.02
# Palau                  460.0     20920.0            9.86    30.38      31.85
# Saint Kitts and Nevis  260.0     54340.0           10.62    28.23      30.51
# San Marino              60.0     32160.0             NaN      NaN        NaN
# Seychelles             460.0     87420.0           12.11    25.56      27.97
# Tuvalu                  30.0      9888.0            2.14      NaN        NaN
#
#                        car_deaths_per_100000_people  calories_per_day  \
# name
# Andorra                                         NaN               NaN
# Antigua and Barbuda                             NaN            2417.0
# Dominica                                        NaN            2931.0
# Liechtenstein                                   NaN               NaN
# Marshall Islands                              1.800               NaN
# Monaco                                          NaN               NaN
# Nauru                                           NaN               NaN
# Palau                                        10.730               NaN
# Saint Kitts and Nevis                           NaN            2492.0
# San Marino                                    5.946               NaN
# Seychelles                                   11.700               NaN
# Tuvalu                                          NaN               NaN
#
#                        infant_mortality  life_expectancy  \
# name
# Andorra                            2.10            82.55
# Antigua and Barbuda                5.80            77.60
# Dominica                          19.60            73.01
# Liechtenstein                      1.76              NaN
# Marshall Islands                  29.60            65.00
# Monaco                             2.80              NaN
# Nauru                             29.10              NaN
# Palau                             14.20              NaN
# Saint Kitts and Nevis              8.40              NaN
# San Marino                         2.60              NaN
# Seychelles                        11.70            74.23
# Tuvalu                            22.80              NaN
#
#                        life_expectancy_female  life_expectancy_male  \
# name
# Andorra                                   NaN                   NaN
# Antigua and Barbuda                    79.028                74.154
# Dominica                                  NaN                   NaN
# Liechtenstein                             NaN                   NaN
# Marshall Islands                          NaN                   NaN
# Monaco                                    NaN                   NaN
# Nauru                                     NaN                   NaN
# Palau                                     NaN                   NaN
# Saint Kitts and Nevis                     NaN                   NaN
# San Marino                                NaN                   NaN
# Seychelles                             78.730                69.693
# Tuvalu                                    NaN                   NaN
#
#                       un_accession
# name
# Andorra                 1993-07-28
# Antigua and Barbuda     1981-11-11
# Dominica                1978-12-18
# Liechtenstein           1990-09-18
# Marshall Islands        1991-09-17
# Monaco                  1993-05-28
# Nauru                   1999-09-14
# Palau                   1994-12-15
# Saint Kitts and Nevis   1983-09-23
# San Marino              1992-03-02
# Seychelles              1976-09-21
# Tuvalu                  2000-09-05

# %% [markdown]
# ...a samozřejmě kombinace:

# %%
# Chudší země EU
countries[countries["is_eu"] & (countries["income_groups"] != "high_income")]
# Out:
#           iso        world_6region world_4region        income_groups  is_eu  \
# name
# Bulgaria  BGR  europe_central_asia        europe  upper_middle_income   True
# Hungary   HUN  europe_central_asia        europe  upper_middle_income   True
# Romania   ROU  europe_central_asia        europe  upper_middle_income   True
#
#           is_oecd eu_accession  year      area  population  alcohol_adults  \
# name
# Bulgaria    False   2007-01-01  2018  111000.0   7349000.0           11.40
# Hungary      True   2004-05-01  2018   93030.0   9934000.0           16.12
# Romania     False   2007-01-01  2018  238390.0  21340000.0           16.15
#
#           bmi_men  bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Bulgaria    26.54      25.52                         9.662            2829.0
# Hungary     27.12      25.98                         5.234            3037.0
# Romania     25.41      25.22                         8.808            3358.0
#
#           infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Bulgaria               9.3            75.32                  78.485
# Hungary                5.3            75.90                  79.557
# Romania                9.7            75.53                  79.158
#
#           life_expectancy_male un_accession
# name
# Bulgaria                71.618   1955-12-14
# Hungary                 72.610   1955-12-14
# Romania                 72.265   1955-12-14

# %%
# Které země OECD mají očekávanou dobu dožití méně 78 let?
countries[countries["is_oecd"] & (countries["life_expectancy"] < 78)]
# Out:
#            iso        world_6region world_4region        income_groups  is_eu  \
# name
# Estonia    EST  europe_central_asia        europe          high_income   True
# Hungary    HUN  europe_central_asia        europe  upper_middle_income   True
# Latvia     LVA  europe_central_asia        europe          high_income   True
# Lithuania  LTU  europe_central_asia        europe          high_income   True
# Mexico     MEX              america      americas  upper_middle_income  False
# Slovakia   SVK  europe_central_asia        europe          high_income   True
#
#            is_oecd eu_accession  year       area   population  alcohol_adults  \
# name
# Estonia       True   2004-05-01  2018    45230.0    1339000.0           17.24
# Hungary       True   2004-05-01  2018    93030.0    9934000.0           16.12
# Latvia        True   2004-05-01  2018    64490.0    2226000.0           13.45
# Lithuania     True   2004-05-01  2018    65286.0    3278000.0           16.30
# Mexico        True          NaN  2018  1964380.0  117500000.0            8.55
# Slovakia      True   2004-05-01  2018    49035.0    5489000.0           13.31
#
#            bmi_men  bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Estonia      26.26      25.19                         5.896            3253.0
# Hungary      27.12      25.98                         5.234            3037.0
# Latvia       26.46      25.62                         8.275            3174.0
# Lithuania    26.86      26.01                         8.090            3417.0
# Mexico       27.42      28.74                         9.468            3072.0
# Slovakia     26.93      26.32                         6.746            2944.0
#
#            infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Estonia                 2.3            77.66                  82.111
# Hungary                 5.3            75.90                  79.557
# Latvia                  6.9            75.13                  79.498
# Lithuania               3.3            75.31                  80.060
# Mexico                 11.3            76.78                  79.880
# Slovakia                5.8            77.16                  80.511
#
#            life_expectancy_male un_accession
# name
# Estonia                  73.201   1991-09-17
# Hungary                  72.610   1955-12-14
# Latvia                   69.882   1991-09-17
# Lithuania                69.554   1991-09-17
# Mexico                   75.120   1945-11-07
# Slovakia                 73.589   1993-01-19

# %% [markdown]
# Protože tento způsob filtrování je poněkud nešikovný, existuje ještě metoda `query`, která umožňuje vybírat řádky na základě řetězce, který popisuje nějakou (ne)rovnost z názvů sloupců a číselných hodnot (což poměrně často jde, někdy ovšem nemusí).

# %%
# Opravdu veliké země (počet obyvatel nad 100 milionů)
countries.query("population > 100_000_000")
# Out:
#                iso        world_6region world_4region        income_groups  \
# name
# Bangladesh     BGD           south_asia          asia           low_income
# Brazil         BRA              america      americas  upper_middle_income
# China          CHN    east_asia_pacific          asia  upper_middle_income
# India          IND           south_asia          asia  lower_middle_income
# Indonesia      IDN    east_asia_pacific          asia  lower_middle_income
# Japan          JPN    east_asia_pacific          asia          high_income
# Mexico         MEX              america      americas  upper_middle_income
# Nigeria        NGA   sub_saharan_africa        africa  lower_middle_income
# Pakistan       PAK           south_asia          asia  lower_middle_income
# Russia         RUS  europe_central_asia        europe          high_income
# United States  USA              america      americas          high_income
#
#                is_eu  is_oecd eu_accession  year        area    population  \
# name
# Bangladesh     False    False          NaN  2018    147630.0  1.544000e+08
# Brazil         False    False          NaN  2018   8515770.0  2.001000e+08
# China          False    False          NaN  2018   9562911.0  1.359000e+09
# India          False    False          NaN  2018   3287259.0  1.275000e+09
# Indonesia      False    False          NaN  2018   1910931.0  2.472000e+08
# Japan          False     True          NaN  2018    377962.0  1.263000e+08
# Mexico         False     True          NaN  2018   1964380.0  1.175000e+08
# Nigeria        False    False          NaN  2018    923770.0  1.709000e+08
# Pakistan       False    False          NaN  2018    796100.0  1.832000e+08
# Russia         False    False          NaN  2018  17098250.0  1.426000e+08
# United States  False     True          NaN  2018   9831510.0  3.185000e+08
#
#                alcohol_adults  bmi_men  bmi_women  \
# name
# Bangladesh               0.17    20.40      20.55
# Brazil                  10.08    25.79      25.99
# China                    5.56    22.92      22.91
# India                    2.69    20.96      21.31
# Indonesia                0.56    21.86      22.99
# Japan                    7.79    23.50      21.87
# Mexico                   8.55    27.42      28.74
# Nigeria                 12.72    23.03      23.67
# Pakistan                 0.05    22.30      23.45
# Russia                  16.23    26.01      27.21
# United States            9.70    28.46      28.34
#
#                car_deaths_per_100000_people  calories_per_day  \
# name
# Bangladesh                            4.401            2450.0
# Brazil                                1.872            3263.0
# China                                 3.590            3108.0
# India                                 3.034            2459.0
# Indonesia                             1.232            2777.0
# Japan                                 1.381            2726.0
# Mexico                                9.468            3072.0
# Nigeria                                 NaN            2700.0
# Pakistan                                NaN            2440.0
# Russia                               14.380            3361.0
# United States                         9.523            3682.0
#
#                infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Bangladesh                 30.7            73.41                  74.937
# Brazil                     14.6            75.70                  79.527
# China                       9.2            76.92                  78.163
# India                      37.9            69.10                  70.678
# Indonesia                  22.8            72.03                  71.742
# Japan                       2.0            84.17                  87.244
# Mexico                     11.3            76.78                  79.880
# Nigeria                    69.4            66.14                  55.158
# Pakistan                   65.8            67.96                  67.869
# Russia                      8.2            71.07                  76.882
# United States               5.6            79.14                  81.942
#
#                life_expectancy_male un_accession
# name
# Bangladesh                   71.484   1974-09-17
# Brazil                       72.340   1945-10-24
# China                        75.096   1945-10-24
# India                        67.538   1945-10-30
# Indonesia                    67.426   1950-09-28
# Japan                        80.803   1956-12-18
# Mexico                       75.120   1945-11-07
# Nigeria                      53.512   1960-10-07
# Pakistan                     65.750   1947-09-30
# Russia                       65.771   1945-10-24
# United States                77.429   1945-10-24

# %%
# V kterých zemích EU se hodně jí?
countries.query("is_eu & (calories_per_day > 3500)")
# Out:
#             iso        world_6region world_4region income_groups  is_eu  \
# name
# Austria     AUT  europe_central_asia        europe   high_income   True
# Belgium     BEL  europe_central_asia        europe   high_income   True
# Ireland     IRL  europe_central_asia        europe   high_income   True
# Italy       ITA  europe_central_asia        europe   high_income   True
# Luxembourg  LUX  europe_central_asia        europe   high_income   True
#
#             is_oecd eu_accession  year      area  population  alcohol_adults  \
# name
# Austria        True   1995-01-01  2018   83879.0   8441000.0           12.40
# Belgium        True   1952-07-23  2018   30530.0  10820000.0           10.41
# Ireland        True   1973-01-01  2018   70280.0   4631000.0           14.92
# Italy          True   1952-07-23  2018  301340.0  61090000.0            9.72
# Luxembourg     True   1952-07-23  2018    2590.0    530000.0           12.84
#
#             bmi_men  bmi_women  car_deaths_per_100000_people  \
# name
# Austria       26.47      25.09                         3.541
# Belgium       26.76      25.14                         5.427
# Ireland       27.65      26.62                         3.768
# Italy         26.48      24.79                         3.778
# Luxembourg    27.43      26.09                         5.971
#
#             calories_per_day  infant_mortality  life_expectancy  \
# name
# Austria               3768.0               2.9            81.84
# Belgium               3733.0               3.3            81.23
# Ireland               3600.0               3.0            81.49
# Italy                 3579.0               2.9            82.62
# Luxembourg            3539.0               1.5            82.39
#
#             life_expectancy_female  life_expectancy_male un_accession
# name
# Austria                     84.249                79.585   1955-12-14
# Belgium                     83.751                79.131   1945-12-27
# Ireland                     83.737                79.885   1955-12-14
# Italy                       85.435                81.146   1955-12-14
# Luxembourg                  84.227                79.981   1945-10-24

# %% [markdown]
# **Úkol**: Která jediná země Afriky patří do skupiny s vysokými příjmy?

# %% [markdown]
# **Úkol**: Ve kterých zemích se pije opravdu hodně (použij výše uvedené nebo jakékoliv jiné kritérium)

# %% [markdown]
# ## Řazení

# %% [markdown]
# V úvodní lekci `pandas` jsme si již ukázali, jak pomocí metody `sort_index` seřadit řádky podle indexu. Jelikož `countries` už jsou srovnané, vyzkoušíme si to ještě jednou na planetách:

# %%
planety.sort_index()
# Out:
#         symbol  obezna_poloosa  obezna_doba  mesice je_obr
# jmeno
# Jupiter      ♃            5.20        11.86      79   True
# Mars         ♂            1.52         1.88       2  False
# Merkur       ☿            0.39         0.24       0  False
# Neptun       ♆           30.06       164.80      14   True
# Saturn       ♄            9.54        29.46      82   True
# Uran         ♅           19.22        84.01      27   True
# Venuše       ♀            0.72         0.62       0  False
# Země         ⊕            1.00         1.00       1  False

# %% [markdown]
# Pro řazení hodnot v `Series` se použije metoda `sort_values`:

# %%
# 10 zemí s nejmenším počtem obyvatel
countries["population"].sort_values().head(10)
# Out:
# name
# Tuvalu                    9888.0
# Nauru                    10440.0
# Palau                    20920.0
# San Marino               32160.0
# Monaco                   35460.0
# Liechtenstein            36870.0
# Saint Kitts and Nevis    54340.0
# Marshall Islands         56690.0
# Dominica                 67700.0
# Seychelles               87420.0
# Name: population, dtype: float64

# %% [markdown]
# Nepovinný argument `ascending` říká, kterým směrem máme řadit. Výchozí hodnota je `True`, změnou na `False` tedy budeme řadit od největšího k nejmenšímu:

# %%
# Největších 10 zemí podle rozlohy
countries["area"].sort_values(ascending=False).head(10)
# Out:
# name
# Russia           17098250.0
# Canada            9984670.0
# United States     9831510.0
# China             9562911.0
# Brazil            8515770.0
# Australia         7741220.0
# India             3287259.0
# Argentina         2780400.0
# Kazakhstan        2724902.0
# Algeria           2381740.0
# Name: area, dtype: float64

# %% [markdown]
# V případě tabulky je třeba jako první argument uvést jméno sloupce (nebo sloupců), podle kterých chceme řadit:

# %%
# 10 zemí s největší spotřebou alkoholu na jednoho obyvatele
countries.sort_values("alcohol_adults", ascending=False).head(10)
# Out:
#              iso        world_6region world_4region        income_groups  \
# name
# Moldova      MDA  europe_central_asia        europe  lower_middle_income
# South Korea  KOR    east_asia_pacific          asia          high_income
# Belarus      BLR  europe_central_asia        europe  upper_middle_income
# North Korea  PRK    east_asia_pacific          asia           low_income
# Ukraine      UKR  europe_central_asia        europe  lower_middle_income
# Estonia      EST  europe_central_asia        europe          high_income
# Czechia      CZE  europe_central_asia        europe          high_income
# Uganda       UGA   sub_saharan_africa        africa           low_income
# Lithuania    LTU  europe_central_asia        europe          high_income
# Russia       RUS  europe_central_asia        europe          high_income
#
#              is_eu  is_oecd eu_accession  year        area   population  \
# name
# Moldova      False    False          NaN  2018     33850.0    3496000.0
# South Korea  False     True          NaN  2018    100280.0   48770000.0
# Belarus      False    False          NaN  2018    207600.0    9498000.0
# North Korea  False    False          NaN  2018    120540.0   24650000.0
# Ukraine      False    False          NaN  2018    603550.0   44700000.0
# Estonia       True     True   2004-05-01  2018     45230.0    1339000.0
# Czechia       True     True   2004-05-01  2018     78870.0   10590000.0
# Uganda       False    False          NaN  2018    241550.0   36760000.0
# Lithuania     True     True   2004-05-01  2018     65286.0    3278000.0
# Russia       False    False          NaN  2018  17098250.0  142600000.0
#
#              alcohol_adults  bmi_men  bmi_women  car_deaths_per_100000_people  \
# name
# Moldova               23.01    24.24      27.06                         5.529
# South Korea           19.15    23.99      23.33                         4.319
# Belarus               18.85    26.16      26.64                         8.454
# North Korea           18.28    22.02      21.25                           NaN
# Ukraine               17.47    25.42      26.23                         8.771
# Estonia               17.24    26.26      25.19                         5.896
# Czechia               16.47    27.91      26.51                         5.720
# Uganda                16.40    22.36      22.48                        13.690
# Lithuania             16.30    26.86      26.01                         8.090
# Russia                16.23    26.01      27.21                        14.380
#
#              calories_per_day  infant_mortality  life_expectancy  \
# name
# Moldova                2714.0              13.6            72.41
# South Korea            3334.0               2.9            81.35
# Belarus                3250.0               3.4            73.76
# North Korea            2094.0              19.7            71.13
# Ukraine                3138.0               7.7            72.29
# Estonia                3253.0               2.3            77.66
# Czechia                3256.0               2.8            79.37
# Uganda                 2130.0              37.7            62.86
# Lithuania              3417.0               3.3            75.31
# Russia                 3361.0               8.2            71.07
#
#              life_expectancy_female  life_expectancy_male un_accession
# name
# Moldova                      76.090                67.544   1992-03-02
# South Korea                  85.467                79.456   1991-09-17
# Belarus                      78.583                67.693   1945-10-24
# North Korea                  75.512                68.450   1991-09-17
# Ukraine                      77.067                67.246   1945-10-24
# Estonia                      82.111                73.201   1991-09-17
# Czechia                      81.858                76.148   1993-01-19
# Uganda                       62.667                58.252   1962-10-25
# Lithuania                    80.060                69.554   1991-09-17
# Russia                       76.882                65.771   1945-10-24

# %% [markdown]
# 💡 V následující buňce je celý kód uzavřen do závorky. Umožnili jsme si tím roztáhnout jeden výraz na více řádků, abychom jeho části mohli náležitě okomentovat.

# %%
(
    # Uvažuj jenom EU
    countries[countries["is_eu"]]
    
    # Seřaď nejdřív podle data vstupu do EU, pak podle vstupu do OSN
    .sort_values(["eu_accession", "un_accession"])

    # Zobraz si jen ty dva sloupce
    [["eu_accession", "un_accession"]]
)
# Out:
#                eu_accession un_accession
# name
# France           1952-07-23   1945-10-24
# Luxembourg       1952-07-23   1945-10-24
# Netherlands      1952-07-23   1945-12-10
# Belgium          1952-07-23   1945-12-27
# Italy            1952-07-23   1955-12-14
# Germany          1952-07-23   1973-09-18
# Denmark          1973-01-01   1945-10-24
# United Kingdom   1973-01-01   1945-10-24
# Ireland          1973-01-01   1955-12-14
# Greece           1981-01-01   1945-10-25
# Portugal         1986-01-01   1955-12-14
# Spain            1986-01-01   1955-12-14
# Sweden           1995-01-01   1946-11-19
# Austria          1995-01-01   1955-12-14
# Finland          1995-01-01   1955-12-14
# Poland           2004-05-01   1945-10-24
# Hungary          2004-05-01   1955-12-14
# Cyprus           2004-05-01   1960-09-20
# Malta            2004-05-01   1964-12-01
# Estonia          2004-05-01   1991-09-17
# Latvia           2004-05-01   1991-09-17
# Lithuania        2004-05-01   1991-09-17
# Slovenia         2004-05-01   1992-05-22
# Czechia          2004-05-01   1993-01-19
# Slovakia         2004-05-01   1993-01-19
# Bulgaria         2007-01-01   1955-12-14
# Romania          2007-01-01   1955-12-14
# Croatia          2013-01-01   1992-05-22

# %% [markdown]
# 💡 Ostatně je možné řadit nejen řádky, ale i sloupce. Následující příklad rovná sloupce podle jejich názvu (indexu). Poslouží k tomu (podobně jako v jiných podobných případech) argument `axis`.

# %%
countries.sort_index(axis="columns")
# Out:
#                         alcohol_adults       area  bmi_men  bmi_women  \
# name
# Afghanistan                       0.03   652860.0    20.62      21.07
# Albania                           7.29    28750.0    26.45      25.66
# Algeria                           0.69  2381740.0    24.60      26.37
# Andorra                          10.17      470.0    27.63      26.43
# Angola                            5.57  1246700.0    22.25      23.48
# Antigua and Barbuda               8.17      440.0    25.77      27.51
# Argentina                         9.35  2780400.0    27.50      27.47
# Armenia                          13.66    29740.0    25.36      27.13
# Australia                        10.21  7741220.0    27.56      26.88
# Austria                          12.40    83879.0    26.47      25.09
# Azerbaijan                       13.34    86600.0    25.65      27.51
# Bahamas                           8.65    13880.0    27.25      29.14
# Bahrain                           4.19      771.0    27.84      28.79
# Bangladesh                        0.17   147630.0    20.40      20.55
# Barbados                          6.42      430.0    26.38      29.22
# Belarus                          18.85   207600.0    26.16      26.64
# Belgium                          10.41    30530.0    26.76      25.14
# Belize                            5.92    22970.0    27.02      29.82
# Benin                             2.08   114760.0    22.42      23.74
# Bhutan                            0.54    38394.0    22.82      22.88
# Bolivia                           5.78  1098580.0    24.43      26.86
# Bosnia and Herzegovina            9.60    51210.0    26.61      26.36
# Botswana                          6.97   581730.0    22.13      26.09
# Brazil                           10.08  8515770.0    25.79      25.99
# Brunei                            1.86     5770.0    24.18      22.89
# Bulgaria                         11.40   111000.0    26.54      25.52
# Burkina Faso                      7.32   274220.0    21.27      21.63
# Burundi                           9.65    27830.0    21.50      21.28
# Cambodia                          4.71   181040.0    20.80      21.70
# Cameroon                          7.90   475440.0    23.68      24.95
# ...                                ...        ...      ...        ...
# Sudan                             2.56  1879357.5    22.40      23.16
# Suriname                          6.56   163820.0    25.50      27.75
# Swaziland                         5.05    17360.0    23.17      28.45
# Sweden                            9.50   447420.0    26.38      25.15
# Switzerland                      11.41    41290.0    26.20      24.07
# Syria                             1.49   185180.0    26.92      28.87
# Tajikistan                        3.39   141376.0    23.78      23.85
# Tanzania                          7.86   947300.0    22.48      23.08
# Thailand                          7.08   513120.0    23.01      24.39
# Timor-Leste                       0.74    14870.0    20.59      21.51
# Togo                              1.92    56790.0    21.88      22.74
# Tonga                             3.92      750.0    31.00      34.26
# Trinidad and Tobago               6.16     5130.0    26.40      28.28
# Tunisia                           1.05   163610.0    25.16      27.94
# Turkey                            3.02   785350.0    26.70      28.25
# Turkmenistan                      5.00   488100.0    25.25      24.66
# Tuvalu                            2.14       30.0      NaN        NaN
# Uganda                           16.40   241550.0    22.36      22.48
# Ukraine                          17.47   603550.0    25.42      26.23
# United Arab Emirates              0.52    83600.0    28.05      29.61
# United Kingdom                   13.24   243610.0    27.39      26.94
# United States                     9.70  9831510.0    28.46      28.34
# Uruguay                           8.99   176220.0    26.39      26.59
# Uzbekistan                        3.61   447400.0    25.32      25.43
# Vanuatu                           0.96    12190.0    26.79      28.46
# Venezuela                         7.60   912050.0    27.45      28.13
# Vietnam                           3.91   330967.0    20.92      21.07
# Yemen                             0.20   527970.0    24.44      26.11
# Zambia                            3.56   752610.0    20.68      23.05
# Zimbabwe                          4.96   390760.0    22.03      24.65
#
#                         calories_per_day  car_deaths_per_100000_people  \
# name
# Afghanistan                       2090.0                           NaN
# Albania                           3193.0                         5.978
# Algeria                           3296.0                           NaN
# Andorra                              NaN                           NaN
# Angola                            2473.0                           NaN
# Antigua and Barbuda               2417.0                           NaN
# Argentina                         3229.0                         8.682
# Armenia                           2928.0                         7.899
# Australia                         3276.0                         5.335
# Austria                           3768.0                         3.541
# Azerbaijan                        3118.0                         5.279
# Bahamas                           2670.0                         9.408
# Bahrain                              NaN                         8.190
# Bangladesh                        2450.0                         4.401
# Barbados                          2937.0                         8.770
# Belarus                           3250.0                         8.454
# Belgium                           3733.0                         5.427
# Belize                            2751.0                        23.040
# Benin                             2619.0                        13.120
# Bhutan                               NaN                           NaN
# Bolivia                           2256.0                        11.740
# Bosnia and Herzegovina            3154.0                         6.405
# Botswana                          2326.0                        29.570
# Brazil                            3263.0                         1.872
# Brunei                            2985.0                        11.670
# Bulgaria                          2829.0                         9.662
# Burkina Faso                      2720.0                        19.400
# Burundi                              NaN                           NaN
# Cambodia                          2477.0                         1.972
# Cameroon                          2671.0                        20.460
# ...                                  ...                           ...
# Sudan                             2336.0                        11.790
# Suriname                          2753.0                         8.573
# Swaziland                         2329.0                        20.150
# Sweden                            3179.0                         2.737
# Switzerland                       3391.0                         2.342
# Syria                                NaN                           NaN
# Tajikistan                        2201.0                         9.448
# Tanzania                          2208.0                        16.550
# Thailand                          2784.0                         2.101
# Timor-Leste                       2131.0                           NaN
# Togo                              2454.0                           NaN
# Tonga                                NaN                         3.850
# Trinidad and Tobago               3052.0                         9.447
# Tunisia                           3349.0                        19.290
# Turkey                            3706.0                         7.189
# Turkmenistan                      2840.0                           NaN
# Tuvalu                               NaN                           NaN
# Uganda                            2130.0                        13.690
# Ukraine                           3138.0                         8.771
# United Arab Emirates              3280.0                        31.850
# United Kingdom                    3424.0                         3.377
# United States                     3682.0                         9.523
# Uruguay                           3050.0                         2.566
# Uzbekistan                        2760.0                         6.418
# Vanuatu                           2836.0                           NaN
# Venezuela                         2631.0                         7.332
# Vietnam                           2745.0                           NaN
# Yemen                             2223.0                           NaN
# Zambia                            1930.0                        11.260
# Zimbabwe                          2110.0                        20.850
#
#                        eu_accession        income_groups  infant_mortality  \
# name
# Afghanistan                     NaN           low_income              66.3
# Albania                         NaN  upper_middle_income              12.5
# Algeria                         NaN  upper_middle_income              21.9
# Andorra                         NaN          high_income               2.1
# Angola                          NaN  upper_middle_income              96.0
# Antigua and Barbuda             NaN          high_income               5.8
# Argentina                       NaN  upper_middle_income              11.1
# Armenia                         NaN  lower_middle_income              12.6
# Australia                       NaN          high_income               3.0
# Austria                  1995-01-01          high_income               2.9
# Azerbaijan                      NaN  upper_middle_income              27.9
# Bahamas                         NaN          high_income               9.9
# Bahrain                         NaN          high_income               5.3
# Bangladesh                      NaN           low_income              30.7
# Barbados                        NaN          high_income              12.0
# Belarus                         NaN  upper_middle_income               3.4
# Belgium                  1952-07-23          high_income               3.3
# Belize                          NaN  upper_middle_income              14.2
# Benin                           NaN           low_income              64.2
# Bhutan                          NaN  lower_middle_income              27.2
# Bolivia                         NaN  lower_middle_income              30.6
# Bosnia and Herzegovina          NaN  upper_middle_income               5.1
# Botswana                        NaN  upper_middle_income              34.8
# Brazil                          NaN  upper_middle_income              14.6
# Brunei                          NaN          high_income               8.6
# Bulgaria                 2007-01-01  upper_middle_income               9.3
# Burkina Faso                    NaN           low_income              60.9
# Burundi                         NaN           low_income              54.1
# Cambodia                        NaN           low_income              24.6
# Cameroon                        NaN  lower_middle_income              57.1
# ...                             ...                  ...               ...
# Sudan                           NaN  lower_middle_income              47.6
# Suriname                        NaN  upper_middle_income              19.0
# Swaziland                       NaN  lower_middle_income              44.5
# Sweden                   1995-01-01          high_income               2.4
# Switzerland                     NaN          high_income               3.4
# Syria                           NaN  lower_middle_income              11.1
# Tajikistan                      NaN           low_income              38.5
# Tanzania                        NaN           low_income              35.2
# Thailand                        NaN  upper_middle_income              10.5
# Timor-Leste                     NaN  lower_middle_income              44.7
# Togo                            NaN           low_income              52.3
# Tonga                           NaN  upper_middle_income              14.4
# Trinidad and Tobago             NaN          high_income              18.2
# Tunisia                         NaN  upper_middle_income              12.1
# Turkey                          NaN  upper_middle_income              11.6
# Turkmenistan                    NaN  upper_middle_income              43.7
# Tuvalu                          NaN  upper_middle_income              22.8
# Uganda                          NaN           low_income              37.7
# Ukraine                         NaN  lower_middle_income               7.7
# United Arab Emirates            NaN          high_income               5.9
# United Kingdom           1973-01-01          high_income               3.5
# United States                   NaN          high_income               5.6
# Uruguay                         NaN          high_income               8.7
# Uzbekistan                      NaN  lower_middle_income              33.9
# Vanuatu                         NaN  lower_middle_income              23.1
# Venezuela                       NaN  upper_middle_income              12.9
# Vietnam                         NaN  lower_middle_income              17.3
# Yemen                           NaN  lower_middle_income              33.8
# Zambia                          NaN  lower_middle_income              43.3
# Zimbabwe                        NaN           low_income              46.6
#
#                         is_eu  is_oecd  iso  life_expectancy  \
# name
# Afghanistan             False    False  AFG            58.69
# Albania                 False    False  ALB            78.01
# Algeria                 False    False  DZA            77.86
# Andorra                 False    False  AND            82.55
# Angola                  False    False  AGO            65.19
# Antigua and Barbuda     False    False  ATG            77.60
# Argentina               False    False  ARG            76.97
# Armenia                 False    False  ARM            75.97
# Australia               False     True  AUS            82.87
# Austria                  True     True  AUT            81.84
# Azerbaijan              False    False  AZE            72.30
# Bahamas                 False    False  BHS            74.10
# Bahrain                 False    False  BHR            77.18
# Bangladesh              False    False  BGD            73.41
# Barbados                False    False  BRB            76.84
# Belarus                 False    False  BLR            73.76
# Belgium                  True     True  BEL            81.23
# Belize                  False    False  BLZ            72.45
# Benin                   False    False  BEN            64.98
# Bhutan                  False    False  BTN            74.83
# Bolivia                 False    False  BOL            73.97
# Bosnia and Herzegovina  False    False  BIH            77.93
# Botswana                False    False  BWA            66.92
# Brazil                  False    False  BRA            75.70
# Brunei                  False    False  BRN            77.36
# Bulgaria                 True    False  BGR            75.32
# Burkina Faso            False    False  BFA            61.60
# Burundi                 False    False  BDI            61.14
# Cambodia                False    False  KHM            69.35
# Cameroon                False    False  CMR            61.22
# ...                       ...      ...  ...              ...
# Sudan                   False    False  SDN            68.77
# Suriname                False    False  SUR            71.62
# Swaziland               False    False  SWZ            58.64
# Sweden                   True     True  SWE            82.37
# Switzerland             False     True  CHE            83.45
# Syria                   False    False  SYR            69.82
# Tajikistan              False    False  TJK            72.19
# Tanzania                False    False  TZA            65.46
# Thailand                False    False  THA            78.15
# Timor-Leste             False    False  TLS            73.34
# Togo                    False    False  TGO            63.09
# Tonga                   False    False  TON            70.70
# Trinidad and Tobago     False    False  TTO            73.37
# Tunisia                 False    False  TUN            77.96
# Turkey                  False     True  TUR            79.61
# Turkmenistan            False    False  TKM            70.48
# Tuvalu                  False    False  TUV              NaN
# Uganda                  False    False  UGA            62.86
# Ukraine                 False    False  UKR            72.29
# United Arab Emirates    False    False  ARE            76.89
# United Kingdom           True     True  GBR            81.19
# United States           False     True  USA            79.14
# Uruguay                 False    False  URY            77.57
# Uzbekistan              False    False  UZB            70.50
# Vanuatu                 False    False  VUT            64.30
# Venezuela               False    False  VEN            75.91
# Vietnam                 False    False  VNM            74.88
# Yemen                   False    False  YEM            67.14
# Zambia                  False    False  ZMB            59.45
# Zimbabwe                False    False  ZWE            60.18
#
#                         life_expectancy_female  life_expectancy_male  \
# name
# Afghanistan                             65.812                63.101
# Albania                                 80.737                76.693
# Algeria                                 77.784                75.279
# Andorra                                    NaN                   NaN
# Angola                                  64.939                59.213
# Antigua and Barbuda                     79.028                74.154
# Argentina                               80.572                73.151
# Armenia                                 77.952                71.589
# Australia                               85.102                81.390
# Austria                                 84.249                79.585
# Azerbaijan                              75.283                69.150
# Bahamas                                 78.894                72.905
# Bahrain                                 78.293                76.318
# Bangladesh                              74.937                71.484
# Barbados                                78.547                73.758
# Belarus                                 78.583                67.693
# Belgium                                 83.751                79.131
# Belize                                  73.828                68.088
# Benin                                   62.960                59.867
# Bhutan                                  71.277                70.567
# Bolivia                                 72.414                67.317
# Bosnia and Herzegovina                  79.729                74.741
# Botswana                                70.753                65.719
# Brazil                                  79.527                72.340
# Brunei                                  79.240                75.954
# Bulgaria                                78.485                71.618
# Burkina Faso                            61.858                60.350
# Burundi                                 60.262                56.246
# Cambodia                                71.690                67.431
# Cameroon                                60.198                57.965
# ...                                        ...                   ...
# Sudan                                   66.553                63.275
# Suriname                                74.992                68.450
# Swaziland                               61.682                55.421
# Sweden                                  84.443                81.126
# Switzerland                             85.475                81.705
# Syria                                   77.763                66.578
# Tajikistan                              74.531                68.557
# Tanzania                                68.527                65.129
# Thailand                                79.459                72.016
# Timor-Leste                             71.421                67.710
# Togo                                    61.571                59.839
# Tonga                                   76.378                70.291
# Trinidad and Tobago                     74.574                67.447
# Tunisia                                 78.207                74.119
# Turkey                                  79.453                73.020
# Turkmenistan                            71.584                64.603
# Tuvalu                                     NaN                   NaN
# Uganda                                  62.667                58.252
# Ukraine                                 77.067                67.246
# United Arab Emirates                    79.081                76.870
# United Kingdom                          83.558                80.127
# United States                           81.942                77.429
# Uruguay                                 81.126                74.217
# Uzbekistan                              74.362                68.721
# Vanuatu                                 74.869                70.393
# Venezuela                               79.079                70.950
# Vietnam                                 81.203                72.003
# Yemen                                   66.871                63.875
# Zambia                                  65.362                59.845
# Zimbabwe                                63.944                60.120
#
#                          population un_accession world_4region  \
# name
# Afghanistan              34500000.0   1946-11-19          asia
# Albania                   3238000.0   1955-12-14        europe
# Algeria                  36980000.0   1962-10-08        africa
# Andorra                     88910.0   1993-07-28        europe
# Angola                   20710000.0   1976-12-01        africa
# Antigua and Barbuda         91400.0   1981-11-11      americas
# Argentina                41470000.0   1945-10-24      americas
# Armenia                   3118000.0   1992-03-02        europe
# Australia                23210000.0   1945-11-01          asia
# Austria                   8441000.0   1955-12-14        europe
# Azerbaijan                9533000.0   1992-03-02        europe
# Bahamas                    355200.0   1973-09-18      americas
# Bahrain                   1377000.0   1971-09-21          asia
# Bangladesh              154400000.0   1974-09-17          asia
# Barbados                   275100.0   1966-12-09      americas
# Belarus                   9498000.0   1945-10-24        europe
# Belgium                  10820000.0   1945-12-27        europe
# Belize                     330700.0   1981-09-25      americas
# Benin                     9607000.0   1960-09-20        africa
# Bhutan                     762300.0   1971-09-21          asia
# Bolivia                  10410000.0   1945-11-14      americas
# Bosnia and Herzegovina    3736000.0   1992-05-22        europe
# Botswana                  2075000.0   1966-10-17        africa
# Brazil                  200100000.0   1945-10-24      americas
# Brunei                     419800.0   1984-09-21          asia
# Bulgaria                  7349000.0   1955-12-14        europe
# Burkina Faso             18010000.0   1960-09-20        africa
# Burundi                   8911000.0   1962-09-18        africa
# Cambodia                 14660000.0   1955-12-14          asia
# Cameroon                 20910000.0   1960-09-20        africa
# ...                             ...          ...           ...
# Sudan                    35940000.0   1956-11-12        africa
# Suriname                   538900.0   1975-12-04      americas
# Swaziland                 1237000.0   1968-09-24        africa
# Sweden                    9546000.0   1946-11-19        europe
# Switzerland               7762000.0   2002-09-10        europe
# Syria                    21470000.0   1945-10-24          asia
# Tajikistan                7184000.0   1992-03-02          asia
# Tanzania                 49150000.0   1961-12-14        africa
# Thailand                 70240000.0   1946-12-16          asia
# Timor-Leste               1224000.0   2002-09-27          asia
# Togo                      6413000.0   1960-09-20        africa
# Tonga                      105300.0   1999-09-14          asia
# Trinidad and Tobago       1355000.0   1962-09-18      americas
# Tunisia                  10810000.0   1956-11-12        africa
# Turkey                   75360000.0   1945-10-24        europe
# Turkmenistan              5235000.0   1992-03-02          asia
# Tuvalu                       9888.0   2000-09-05          asia
# Uganda                   36760000.0   1962-10-25        africa
# Ukraine                  44700000.0   1945-10-24        europe
# United Arab Emirates      8208000.0   1971-12-09          asia
# United Kingdom           63180000.0   1945-10-24        europe
# United States           318500000.0   1945-10-24      americas
# Uruguay                   3403000.0   1945-12-18      americas
# Uzbekistan               28400000.0   1992-03-02          asia
# Vanuatu                    257800.0   1981-09-15          asia
# Venezuela                30340000.0   1945-11-15      americas
# Vietnam                  90660000.0   1977-09-20          asia
# Yemen                    26360000.0   1947-09-30          asia
# Zambia                   14310000.0   1964-12-01        africa
# Zimbabwe                 13330000.0   1980-08-25        africa
#
#                                    world_6region  year
# name
# Afghanistan                           south_asia  2018
# Albania                      europe_central_asia  2018
# Algeria                 middle_east_north_africa  2018
# Andorra                      europe_central_asia  2017
# Angola                        sub_saharan_africa  2018
# Antigua and Barbuda                      america  2018
# Argentina                                america  2018
# Armenia                      europe_central_asia  2018
# Australia                      east_asia_pacific  2018
# Austria                      europe_central_asia  2018
# Azerbaijan                   europe_central_asia  2018
# Bahamas                                  america  2018
# Bahrain                 middle_east_north_africa  2018
# Bangladesh                            south_asia  2018
# Barbados                                 america  2018
# Belarus                      europe_central_asia  2018
# Belgium                      europe_central_asia  2018
# Belize                                   america  2018
# Benin                         sub_saharan_africa  2018
# Bhutan                                south_asia  2018
# Bolivia                                  america  2018
# Bosnia and Herzegovina       europe_central_asia  2018
# Botswana                      sub_saharan_africa  2018
# Brazil                                   america  2018
# Brunei                         east_asia_pacific  2018
# Bulgaria                     europe_central_asia  2018
# Burkina Faso                  sub_saharan_africa  2018
# Burundi                       sub_saharan_africa  2018
# Cambodia                       east_asia_pacific  2018
# Cameroon                      sub_saharan_africa  2018
# ...                                          ...   ...
# Sudan                         sub_saharan_africa  2018
# Suriname                                 america  2018
# Swaziland                     sub_saharan_africa  2018
# Sweden                       europe_central_asia  2018
# Switzerland                  europe_central_asia  2018
# Syria                   middle_east_north_africa  2018
# Tajikistan                   europe_central_asia  2018
# Tanzania                      sub_saharan_africa  2018
# Thailand                       east_asia_pacific  2018
# Timor-Leste                    east_asia_pacific  2018
# Togo                          sub_saharan_africa  2018
# Tonga                          east_asia_pacific  2018
# Trinidad and Tobago                      america  2018
# Tunisia                 middle_east_north_africa  2018
# Turkey                       europe_central_asia  2018
# Turkmenistan                 europe_central_asia  2018
# Tuvalu                         east_asia_pacific  2017
# Uganda                        sub_saharan_africa  2018
# Ukraine                      europe_central_asia  2018
# United Arab Emirates    middle_east_north_africa  2018
# United Kingdom               europe_central_asia  2018
# United States                            america  2018
# Uruguay                                  america  2018
# Uzbekistan                   europe_central_asia  2018
# Vanuatu                        east_asia_pacific  2018
# Venezuela                                america  2018
# Vietnam                        east_asia_pacific  2018
# Yemen                   middle_east_north_africa  2018
# Zambia                        sub_saharan_africa  2018
# Zimbabwe                      sub_saharan_africa  2018
#
# [193 rows x 20 columns]

# %% [markdown]
# **Úkol:** Seřaď země světa podle hustoty obyvatel.

# %% [markdown]
# **Úkol:** Které země mají problémy s nadváhou (průměrné BMI mužů a žen je přes 25)?

# %% [markdown]
# **Úkol:** V kterých 20 zemích umře absolutně nejvíc lidí při automobilových haváriích?

# %% [markdown]
# ## Ulož výsledky!
#
# A tím už pomalu končíme. Jenže jsme udělali (skoro) netriviální množství práce a ta bude do příště ztracená. Naštěstí zapsat `DataFrame` do externího souboru v některém z typických formátů není vůbec komplikované. K sadě funkcí `pd.read_XXX` existují jejich protějšky `DataFrame.to_XXX`. Liší se různými parametry, ale základní použití je velmi jednoduché:

# %%
planety.to_csv("planety.csv")

# %%
planety.to_excel("planety.xlsx")

# %% [markdown]
# Excel ani CSV nejsou formáty pro ukládání velikých dat zcela vhodné - první je vázaný na jeden konkrétní kancelářský balík, druhý zase v textové reprezentaci ztrácí informace o typech, nemluvě o výkonu a datové náročnosti. Z jiných formátů můžeš vyzkoušet například [feather](https://github.com/wesm/feather) nebo [parquet](https://en.wikipedia.org/wiki/Apache_Parquet).

# %%
countries.reset_index().to_feather("countries.feather")   # Pozor: feather neukládá index

# %% [markdown]
# Jednou z možností je i vytvoření HTML tabulky (které lze dodat i různé formátování, což ovšem nechme raději na jindy nebo na doma, viz [dokumentace "Styling"](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)). Výchozí `to_html` si bohužel neporadí s "nezápadními" symboly (což je třeba ☿), a tak mu (v našem konkrétním případě) musíme předat korektně otevřený soubor:

# %%
# planety.to_html("planety.html")     # To (zatím) nefunguje :-(

with open("planety.html", "w", encoding="utf-8") as out:
    planety.to_html(out)

# %%
countries.to_html("countries.html")   # Žádné exotické symboly :-)

# %% [markdown]
# **Úkol**: Podívej se, co ve výstupních souborech najdeš.

# %% [markdown]
# **Úkol**: Podívej se na seznam možných výstupních formátů a zkus si planety nebo země zapsat do nějakého z nich: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#serialization-io-conversion

# %% [markdown]
# A to už je opravdu všechno. 👋
